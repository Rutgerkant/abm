# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

model1 = BaseModelSub()


for i in range(1):
    model1.step()

print("1 stap gelukt")


model1 = SubsidieModel()
model2 = SubsidieModel2()
model3 = SubsidieModel3()


for i in range(240):
    model1.step()
    model2.step()
    model3.step()

model_data1 = model1.datacollector.get_model_vars_dataframe()
model_data2 = model2.datacollector.get_model_vars_dataframe()
model_data3 = model3.datacollector.get_model_vars_dataframe()


print(model_data1)
print(model_data2)
print(model_data3)
# Out:
# 25954.174466040142
# /Users/michielvanhouten/Dropbox/Mac/Documents/GitHub/abm/.venv/lib/python3.9/site-packages/mesa/time.py:82: FutureWarning: The AgentSet is experimental. It may be changed or removed in any and all future releases, including patch releases.
# We would love to hear what you think about this new feature. If you have any thoughts, share them with us here: https://github.com/projectmesa/mesa/discussions/1919
#   self._agents: AgentSet = AgentSet(agents, model)
# 1 stap gelukt
# Stap 2 gelukt
# <function percentage_evs at 0x7f85ba58f430>
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.590216                  64                    9
# 1                     0.590216                 125                   15
# 2                     0.590216                 157                   22
# 3                     0.590216                 185                   26
# 4                     0.590216                 199                   33
# ..                         ...                 ...                  ...
# 235                   0.514739                 676                  379
# 236                   0.514739                 676                  379
# 237                   0.514739                 676                  379
# 238                   0.514739                 676                  379
# 239                   0.513033                 676                  379
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                  0.7344                     0.034858
# 1                                  0.7344                     0.112745
# 2                                  0.7344                     0.156318
# 3                                  0.7344                     0.195534
# 4                                  0.7344                     0.228214
# ..                                    ...                          ...
# 235                                0.7344                     0.952614
# 236                                0.7344                     0.952614
# 237                                0.7344                     0.952614
# 238                                0.7344                     0.952614
# 239                                0.7344                     0.952614
#
#      Hoeveelheid Subsidie
# 0             3966.687000
# 1             3966.687000
# 2             3966.687000
# 3             3966.687000
# 4             3966.687000
# ..                    ...
# 235            936.066496
# 236            936.066496
# 237            936.066496
# 238            936.066496
# 239            867.561599
#
# [240 rows x 6 columns]
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.496407                  33                   17
# 1                     0.496407                  58                   31
# 2                     0.496407                  79                   37
# 3                     0.496407                 112                   47
# 4                     0.496407                 123                   58
# ..                         ...                 ...                  ...
# 235                   0.591046                 544                  347
# 236                   0.591046                 544                  347
# 237                   0.591046                 544                  349
# 238                   0.591046                 544                  350
# 239                   0.591046                 544                  350
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                  0.7344                     0.052832
# 1                                  0.7344                     0.126362
# 2                                  0.7344                     0.167756
# 3                                  0.7344                     0.213508
# 4                                  0.7344                     0.234205
# ..                                    ...                          ...
# 235                                0.7344                     0.952614
# 236                                0.7344                     0.952614
# 237                                0.7344                     0.952614
# 238                                0.7344                     0.952614
# 239                                0.7344                     0.952614
#
#      Hoeveelheid Subsidie
# 0                     200
# 1                     200
# 2                     200
# 3                     200
# 4                     200
# ..                    ...
# 235                  4000
# 236                  4000
# 237                  4000
# 238                  4000
# 239                  4000
#
# [240 rows x 6 columns]
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.503879                  49                   10
# 1                     0.503879                  72                   18
# 2                     0.503879                  95                   25
# 3                     0.503879                 108                   36
# 4                     0.503879                 115                   44
# ..                         ...                 ...                  ...
# 235                   0.591046                 529                  431
# 236                   0.591046                 529                  431
# 237                   0.591046                 529                  431
# 238                   0.591046                 529                  431
# 239                   0.591046                 529                  431
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                  0.7344                     0.079521
# 1                                  0.7344                     0.138889
# 2                                  0.7344                     0.180283
# 3                                  0.7344                     0.220588
# 4                                  0.7344                     0.238017
# ..                                    ...                          ...
# 235                                0.7344                     0.952614
# 236                                0.7344                     0.952614
# 237                                0.7344                     0.952614
# 238                                0.7344                     0.952614
# 239                                0.7344                     0.952614
#
#      Hoeveelheid Subsidie
# 0                   500.0
# 1                   500.0
# 2                   500.0
# 3                   500.0
# 4                   500.0
# ..                    ...
# 235                4000.0
# 236                4000.0
# 237                4000.0
# 238                4000.0
# 239                4000.0
#
# [240 rows x 6 columns]
