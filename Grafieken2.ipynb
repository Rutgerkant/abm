# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

import random
import numpy as np



base_model = BaseModelSub()


for i in range(1):
    base_model.step()

print("1 stap gelukt")


# Seed doorgeven aan elk model
model1 = SubsidieModel(0.74)
model2 = SubsidieModel2(0.74)
model3 = SubsidieModel3(0.74)


for i in range(180):
    model1.step()
    model2.step()
    model3.step()
# Out:
# 35687.50498078785
# 1 stap gelukt
# STAP1
# /Users/michielvanhouten/Dropbox/Mac/Documents/GitHub/abm/.venv/lib/python3.9/site-packages/mesa/time.py:82: FutureWarning: The AgentSet is experimental. It may be changed or removed in any and all future releases, including patch releases.
# We would love to hear what you think about this new feature. If you have any thoughts, share them with us here: https://github.com/projectmesa/mesa/discussions/1919
#   self._agents: AgentSet = AgentSet(agents, model)

# %%
model_data1 = model1.datacollector.get_model_vars_dataframe()
model_data2 = model2.datacollector.get_model_vars_dataframe()
model_data3 = model3.datacollector.get_model_vars_dataframe()

agent_data1 = model1.datacollector.get_agent_vars_dataframe()
agent_data2 = model2.datacollector.get_agent_vars_dataframe()
agent_data3 = model3.datacollector.get_agent_vars_dataframe()

print(model_data1)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.590209                   8                    2
# 1                     0.590209                  11                    2
# 2                     0.590209                  16                    4
# 3                     0.590209                  17                    6
# 4                     0.590209                  22                    6
# ..                         ...                 ...                  ...
# 175                   0.525517                 146                   84
# 176                   0.525517                 146                   84
# 177                   0.525517                 146                   84
# 178                   0.525517                 146                   84
# 179                   0.523022                 146                   84
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                0.205357                     0.049689
# 1                                0.205357                     0.068323
# 2                                0.205357                     0.099379
# 3                                0.205357                     0.105590
# 4                                0.205357                     0.136646
# ..                                    ...                          ...
# 175                              0.205357                     0.906832
# 176                              0.205357                     0.906832
# 177                              0.205357                     0.906832
# 178                              0.205357                     0.906832
# 179                              0.205357                     0.906832
#
#      Hoeveelheid totale Subsidie  Hoeveelheid Subsidie  \
# 0                   31733.496000           3966.687000
# 1                   43633.557000           3966.687000
# 2                   63466.992000           3966.687000
# 3                   67433.679000           3966.687000
# 4                   87267.114000           3966.687000
# ..                           ...                   ...
# 175                414363.742067           1368.795611
# 176                414363.742067           1368.795611
# 177                414363.742067           1368.795611
# 178                414363.742067           1368.795611
# 179                414363.742067           1268.621956
#
#      Percentage late majority met EV  Percentage laggards met EV
# 0                           0.007491                    0.007937
# 1                           0.007491                    0.015873
# 2                           0.007491                    0.023810
# 3                           0.011236                    0.023810
# 4                           0.022472                    0.023810
# ..                               ...                         ...
# 175                         0.187266                    0.190476
# 176                         0.187266                    0.190476
# 177                         0.187266                    0.190476
# 178                         0.187266                    0.190476
# 179                         0.187266                    0.190476
#
# [180 rows x 9 columns]

# %%
print(model_data2)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.496411                   4                    3
# 1                     0.496411                   8                    3
# 2                     0.496411                  11                    4
# 3                     0.496411                  13                    5
# 4                     0.496411                  16                    7
# ..                         ...                 ...                  ...
# 175                   0.566136                 129                   86
# 176                   0.566136                 129                   86
# 177                   0.566136                 129                   86
# 178                   0.566136                 129                   86
# 179                   0.571117                 129                   86
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                0.188776                     0.027027
# 1                                0.188776                     0.054054
# 2                                0.188776                     0.074324
# 3                                0.188776                     0.087838
# 4                                0.188776                     0.108108
# ..                                    ...                          ...
# 175                              0.188776                     0.871622
# 176                              0.188776                     0.871622
# 177                              0.188776                     0.871622
# 178                              0.188776                     0.871622
# 179                              0.188776                     0.871622
#
#      Hoeveelheid totale Subsidie  Hoeveelheid Subsidie  \
# 0                            800                   200
# 1                           1600                   200
# 2                           2200                   200
# 3                           2600                   200
# 4                           3200                   200
# ..                           ...                   ...
# 175                       172800                  3000
# 176                       172800                  3000
# 177                       172800                  3000
# 178                       172800                  3000
# 179                       172800                  3200
#
#      Percentage late majority met EV  Percentage laggards met EV
# 0                           0.007491                    0.000000
# 1                           0.014981                    0.000000
# 2                           0.018727                    0.015873
# 3                           0.022472                    0.015873
# 4                           0.022472                    0.023810
# ..                               ...                         ...
# 175                         0.168539                    0.166667
# 176                         0.168539                    0.166667
# 177                         0.168539                    0.166667
# 178                         0.168539                    0.166667
# 179                         0.168539                    0.166667
#
# [180 rows x 9 columns]

# %%
print(model_data3)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.503882                   5                    1
# 1                     0.503882                   7                    1
# 2                     0.503882                  11                    4
# 3                     0.503882                  18                    4
# 4                     0.503882                  23                    4
# ..                         ...                 ...                  ...
# 175                   0.568276                 141                   91
# 176                   0.568276                 141                   91
# 177                   0.568276                 141                   92
# 178                   0.568276                 142                   92
# 179                   0.578945                 142                   92
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                0.201531                     0.031646
# 1                                0.201531                     0.044304
# 2                                0.201531                     0.069620
# 3                                0.201531                     0.113924
# 4                                0.201531                     0.145570
# ..                                    ...                          ...
# 175                              0.201531                     0.892405
# 176                              0.201531                     0.892405
# 177                              0.201531                     0.892405
# 178                              0.201531                     0.898734
# 179                              0.201531                     0.898734
#
#      Hoeveelheid totale Subsidie  Hoeveelheid Subsidie  \
# 0                    2500.000000            500.000000
# 1                    3500.000000            500.000000
# 2                    5500.000000            500.000000
# 3                    9000.000000            500.000000
# 4                   11500.000000            500.000000
# ..                           ...                   ...
# 175                183998.631591           3085.929225
# 176                183998.631591           3085.929225
# 177                183998.631591           3085.929225
# 178                187084.560816           3085.929225
# 179                187084.560816           3514.343790
#
#      Percentage late majority met EV  Percentage laggards met EV
# 0                           0.007491                    0.000000
# 1                           0.014981                    0.000000
# 2                           0.014981                    0.023810
# 3                           0.026217                    0.023810
# 4                           0.037453                    0.023810
# ..                               ...                         ...
# 175                         0.183521                    0.182540
# 176                         0.183521                    0.182540
# 177                         0.183521                    0.182540
# 178                         0.183521                    0.190476
# 179                         0.183521                    0.190476
#
# [180 rows x 9 columns]

# %%
print(vars(model1.schedule.agents[0]))
print(vars(model2.schedule.agents[0]))
print(vars(model3.schedule.agents[0]))
# Out:
# {'unique_id': (10, 20), 'model': <SubsidieModel.SubsidieModel object at 0x7fc9d89e6e20>, 'pos': (10, 20), 'agent_type': <TypeAdopter.LAGGARDS: 4>, 'bezit_auto': False, 'bezit_EV': False, 'vermogen': 387562.5, 'inkomen': 1687.5, 'belangstelling': 0.3955665732552546, 'leeftijd_auto': 180}
# {'unique_id': (13, 4), 'model': <SubsidieModelLinear.SubsidieModel2 object at 0x7fc9c88d1f40>, 'pos': (13, 4), 'agent_type': <TypeAdopter.EARLY_ADOPTER: 1>, 'bezit_auto': False, 'bezit_EV': False, 'vermogen': 205007.7243819025, 'inkomen': 850.0, 'belangstelling': 0.8119999999999999, 'leeftijd_auto': 180}
# {'unique_id': (19, 21), 'model': <SubsidieModel3.SubsidieModel3 object at 0x7fc9a8a66400>, 'pos': (19, 21), 'agent_type': <TypeAdopter.EARLY_MAJORITY: 2>, 'bezit_auto': True, 'bezit_EV': True, 'vermogen': 117911.1665127294, 'inkomen': 525.0, 'belangstelling': 0.6224016261282501, 'leeftijd_auto': 160}

# %%
print(agent_data1)
print(agent_data2)
print(agent_data3)
# Out:
#                    Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (17, 25)   LATE_MAJORITY        0.497234              1    73668.409129
#      (12, 10)   EARLY_ADOPTER        0.835001              1    84925.000000
#      (23, 19)  EARLY_MAJORITY        0.635067              1    18350.455494
#      (12, 23)  EARLY_MAJORITY        0.635067              1    12445.527607
#      (19, 4)   EARLY_MAJORITY        0.635067              1     5789.033442
# ...                       ...             ...            ...             ...
# 180  (4, 24)   EARLY_MAJORITY        0.559521            186   239427.932006
#      (1, 4)     LATE_MAJORITY        0.435178            180   249273.869187
#      (9, 23)    EARLY_ADOPTER        0.754059            180    80503.870369
#      (2, 14)         LAGGARDS        0.395567            180    56918.771667
#      (21, 10)   LATE_MAJORITY        0.435178            180    71982.472988
#
#                agent heeft ev
# Step AgentID
# 1    (17, 25)           False
#      (12, 10)           False
#      (23, 19)           False
#      (12, 23)           False
#      (19, 4)            False
# ...                       ...
# 180  (4, 24)             True
#      (1, 4)             False
#      (9, 23)            False
#      (2, 14)            False
#      (21, 10)           False
#
# [141120 rows x 5 columns]
#                    Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (6, 12)    LATE_MAJORITY          0.4106             38    19143.083157
#      (19, 17)  EARLY_MAJORITY          0.5296             42    85350.000000
#      (15, 19)        LAGGARDS          0.3774             43    12737.554752
#      (20, 21)  EARLY_MAJORITY          0.5296              1    48538.525830
#      (11, 1)    LATE_MAJORITY          0.4106              1    71973.757721
# ...                       ...             ...            ...             ...
# 180  (26, 9)    LATE_MAJORITY          0.4796            241   302062.500000
#      (5, 18)    LATE_MAJORITY          0.4796            180    94053.961876
#      (4, 9)     EARLY_ADOPTER          0.8120            180    83891.518607
#      (17, 1)   EARLY_MAJORITY          0.6136            180    63453.447621
#      (26, 17)   LATE_MAJORITY          0.4796            180   118088.976544
#
#                agent heeft ev
# Step AgentID
# 1    (6, 12)            False
#      (19, 17)           False
#      (15, 19)           False
#      (20, 21)           False
#      (11, 1)            False
# ...                       ...
# 180  (26, 9)             True
#      (5, 18)            False
#      (4, 9)             False
#      (17, 1)            False
#      (26, 17)           False
#
# [141120 rows x 5 columns]
#                    Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (25, 9)    LATE_MAJORITY        0.417500              1    71676.608915
#      (14, 1)         LAGGARDS        0.382500              1    54349.274835
#      (17, 23)        LAGGARDS        0.382500              1    33398.691529
#      (0, 2)     EARLY_ADOPTER        0.731000              1    85237.500000
#      (24, 0)    LATE_MAJORITY        0.417500              1    32731.046199
# ...                       ...             ...            ...             ...
# 180  (13, 6)   EARLY_MAJORITY        0.622402            180   122923.246256
#      (25, 5)    LATE_MAJORITY        0.486830            180   203093.946081
#      (4, 24)   EARLY_MAJORITY        0.622402            180   190533.549211
#      (24, 15)   LATE_MAJORITY        0.486830            180    54061.707327
#      (8, 11)    EARLY_ADOPTER        0.821430            180   189335.988296
#
#                agent heeft ev
# Step AgentID
# 1    (25, 9)            False
#      (14, 1)            False
#      (17, 23)           False
#      (0, 2)             False
#      (24, 0)            False
# ...                       ...
# 180  (13, 6)            False
#      (25, 5)            False
#      (4, 24)            False
#      (24, 15)           False
#      (8, 11)            False
#
# [141120 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Plot instellingen
plt.figure(figsize=(10, 6))

# Lijnen tekenen voor elk model
plt.plot(model_data1['Aantal gekochte EV'], label='Model 1')
plt.plot(model_data2['Aantal gekochte EV'], label='Model 2')
plt.plot(model_data3['Aantal gekochte EV'], label='Model 3')

# Grafiek aankleden
plt.title('Verkoop van EV over tijd')
plt.xlabel('Tijd (stappen)')
plt.ylabel('Aantal gekochte EVs')
plt.legend()  # Voegt de legenda toe
plt.grid(True)

# Toon de grafiek
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2)

x = range(len(model_data1))

# Eerste subplot 
axs[0, 0].plot(x, model_data1["Percerntage EV's van Auto's"], label='Model 1')
axs[0, 0].plot(x, model_data2["Percerntage EV's van Auto's"], label='Model 2')
axs[0, 0].plot(x, model_data3["Percerntage EV's van Auto's"], label='Model 3')

axs[0, 0].set_title("Percentage EV van alle auto's")
axs[0, 0].legend()

# Tweede subplot
axs[0, 1].plot(x, model_data1["Hoeveelheid Subsidie"], label='Model 1')
axs[0, 1].plot(x, model_data2["Hoeveelheid Subsidie"], label='Model 2')
axs[0, 1].plot(x, model_data3["Hoeveelheid Subsidie"], label='Model 3')

axs[0, 1].set_title('Totale hoeveelheid subsidie uitgegeven')
axs[0, 1].legend()


# Derde subplot
axs[1, 0].plot(x, model_data1["Percentage late majority met EV"], label='Model 1')
axs[1, 0].plot(x, model_data2["Percentage late majority met EV"], label='Model 2')
axs[1, 0].plot(x, model_data3["Percentage late majority met EV"], label='Model 3')

axs[1, 0].set_title('Percentage late majority met EV')
axs[1, 0].legend()

# Vierde subplot 
axs[1, 1].plot(x, model_data1['Percentage laggards met EV'], label='Model 1')
axs[1, 1].plot(x, model_data2['Percentage laggards met EV'], label='Model 2')
axs[1, 1].plot(x, model_data3['Percentage laggards met EV'], label='Model 3')

axs[1, 1].set_title("Percentage laggards met EV")
axs[1, 1].legend()

plt.tight_layout()
plt.show()
