# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

import random
import numpy as np

random.seed(42)
np.random.seed(42)

base_model = BaseModelSub(seed=42)


for i in range(1):
    base_model.step()

print("1 stap gelukt")


# Seed doorgeven aan elk model
model1 = SubsidieModel()
model2 = SubsidieModel2()
model3 = SubsidieModel3()


for i in range(240):
    model1.step()
    model2.step()
    model3.step()
# Out:
# 12014.413972461169
# Vermogen, inkomen 29315.869144049127, 675.0
# Vermogen, inkomen 726.2703962817992, 312.5
# Vermogen, inkomen 4029.474139462324, 412.5
# Vermogen, inkomen 83812.5, 1500.0
# Vermogen, inkomen 83812.5, 1812.5
# Vermogen, inkomen 83812.5, 1662.5
# Vermogen, inkomen 39315.97198744057, 850.0
# Vermogen, inkomen 9365.66925035172, 462.5
# Vermogen, inkomen 17372.326182764977, 587.5
# Vermogen, inkomen -187.5, 125.0
# Vermogen, inkomen 28953.590823112587, 650.0
# Vermogen, inkomen -187.5, 225.0
# Vermogen, inkomen 48189.407732424515, 875.0
# Vermogen, inkomen 37.47756680595507, 287.5
# Vermogen, inkomen 32463.780364409842, 737.5
# Vermogen, inkomen 14607.679890283356, 450.0
# Vermogen, inkomen -119.25239735291134, 275.0
# Vermogen, inkomen 29.139898173680706, 237.5
# Vermogen, inkomen 72060.3510334843, 1100.0
# Vermogen, inkomen -187.5, 100.0
# Vermogen, inkomen 60606.04104835871, 925.0
# Vermogen, inkomen -107.2605269391227, 312.5
# Vermogen, inkomen 6042.125097786855, 387.5
# Vermogen, inkomen -187.5, 137.5
# Vermogen, inkomen 63324.68317427043, 987.5
# 1 stap gelukt
# Stap 10
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(0, 19)
# 0
# 25
# Total Evs, Total caars(0, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 5)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 5)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 5)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 5)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 5)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 0)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 3)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 5)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 1)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 2)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# Aantal Autos en aantal EV (25, 4)
# 25
# Total Evs, Total caars(2, 19)
# 2
# 25
# Total Evs, Total caars(2, 19)
# /Users/michielvanhouten/Dropbox/Mac/Documents/GitHub/abm/.venv/lib/python3.9/site-packages/mesa/time.py:82: FutureWarning: The AgentSet is experimental. It may be changed or removed in any and all future releases, including patch releases.
# We would love to hear what you think about this new feature. If you have any thoughts, share them with us here: https://github.com/projectmesa/mesa/discussions/1919
#   self._agents: AgentSet = AgentSet(agents, model)

# %%
model_data1 = model1.datacollector.get_model_vars_dataframe()
model_data2 = model2.datacollector.get_model_vars_dataframe()
model_data3 = model3.datacollector.get_model_vars_dataframe()

agent_data1 = model1.datacollector.get_agent_vars_dataframe()
agent_data2 = model2.datacollector.get_agent_vars_dataframe()
agent_data3 = model3.datacollector.get_agent_vars_dataframe()

print(model_data1)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.593898                   0                    0
# 1                     0.593898                   2                    0
# 2                     0.593898                   2                    0
# 3                     0.593898                   2                    0
# 4                     0.593898                   2                    0
# ..                         ...                 ...                  ...
# 235                   0.519102                   2                    0
# 236                   0.519102                   2                    0
# 237                   0.519102                   2                    0
# 238                   0.519102                   2                    0
# 239                   0.517411                   2                    0
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                    0.76                     0.000000
# 1                                    0.76                     0.105263
# 2                                    0.76                     0.105263
# 3                                    0.76                     0.105263
# 4                                    0.76                     0.105263
# ..                                    ...                          ...
# 235                                  0.76                     0.105263
# 236                                  0.76                     0.105263
# 237                                  0.76                     0.105263
# 238                                  0.76                     0.105263
# 239                                  0.76                     0.105263
#
#      Hoeveelheid Subsidie
# 0             3966.687000
# 1             3966.687000
# 2             3966.687000
# 3             3966.687000
# 4             3966.687000
# ..                    ...
# 235            936.066496
# 236            936.066496
# 237            936.066496
# 238            936.066496
# 239            867.561599
#
# [240 rows x 6 columns]

# %%
print(model_data2)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.496176                   1                    0
# 1                     0.496176                   2                    0
# 2                     0.496176                   2                    0
# 3                     0.496176                   2                    0
# 4                     0.496176                   2                    0
# ..                         ...                 ...                  ...
# 235                   0.589200                   4                    0
# 236                   0.589200                   4                    0
# 237                   0.589200                   4                    0
# 238                   0.589200                   4                    0
# 239                   0.589200                   4                    0
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                    0.88                     0.045455
# 1                                    0.88                     0.090909
# 2                                    0.88                     0.090909
# 3                                    0.88                     0.090909
# 4                                    0.88                     0.090909
# ..                                    ...                          ...
# 235                                  0.88                     0.181818
# 236                                  0.88                     0.181818
# 237                                  0.88                     0.181818
# 238                                  0.88                     0.181818
# 239                                  0.88                     0.181818
#
#      Hoeveelheid Subsidie
# 0                     200
# 1                     200
# 2                     200
# 3                     200
# 4                     200
# ..                    ...
# 235                  4000
# 236                  4000
# 237                  4000
# 238                  4000
# 239                  4000
#
# [240 rows x 6 columns]

# %%
print(model_data3)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                      0.51798                   0                    0
# 1                      0.51798                   0                    0
# 2                      0.51798                   0                    0
# 3                      0.51798                   0                    1
# 4                      0.51798                   0                    1
# ..                         ...                 ...                  ...
# 235                    0.60576                   0                    1
# 236                    0.60576                   0                    1
# 237                    0.60576                   0                    1
# 238                    0.60576                   0                    1
# 239                    0.60576                   0                    1
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                    0.76                          0.0
# 1                                    0.76                          0.0
# 2                                    0.76                          0.0
# 3                                    0.76                          0.0
# 4                                    0.76                          0.0
# ..                                    ...                          ...
# 235                                  0.76                          0.0
# 236                                  0.76                          0.0
# 237                                  0.76                          0.0
# 238                                  0.76                          0.0
# 239                                  0.76                          0.0
#
#      Hoeveelheid Subsidie
# 0                   500.0
# 1                   500.0
# 2                   500.0
# 3                   500.0
# 4                   500.0
# ..                    ...
# 235                4000.0
# 236                4000.0
# 237                4000.0
# 238                4000.0
# 239                4000.0
#
# [240 rows x 6 columns]

# %%
print(vars(model1.schedule.agents[0]))
print(vars(model2.schedule.agents[0]))
print(vars(model3.schedule.agents[0]))
# Out:
# {'unique_id': (0, 3), 'model': <SubsidieModel.SubsidieModel object at 0x7fe48039e9d0>, 'pos': (0, 3), 'agent_type': <TypeAdopter.LATE_MAJORITY: 3>, 'bezit_auto': True, 'bezit_EV': False, 'vermogen': 18816.918379547686, 'inkomen': 550.0, 'belangstelling': 0.4259539167705329, 'leeftijd_auto': 59}
# {'unique_id': (3, 1), 'model': <SubsidieModelLinear.SubsidieModel2 object at 0x7fe470e525b0>, 'pos': (3, 1), 'agent_type': <TypeAdopter.LATE_MAJORITY: 3>, 'bezit_auto': True, 'bezit_EV': False, 'vermogen': 78028.18856564016, 'inkomen': 1025.0, 'belangstelling': 0.498, 'leeftijd_auto': 41}
# {'unique_id': (4, 1), 'model': <SubsidieModel3.SubsidieModel3 object at 0x7fe470e6e160>, 'pos': (4, 1), 'agent_type': <TypeAdopter.LATE_MAJORITY: 3>, 'bezit_auto': True, 'bezit_EV': False, 'vermogen': -187.5, 'inkomen': 137.5, 'belangstelling': 0.498, 'leeftijd_auto': 50}

# %%
print(agent_data1)
print(agent_data2)
print(agent_data3)
# Out:
#                  Type Agent  Belangstelling  leeftijd auto  Vermogen Agent
# Step AgentID
# 1    (2, 3)   LATE_MAJORITY        0.497234             38    18358.396598
#      (2, 4)        LAGGARDS        0.441434             48    56546.448339
#      (1, 0)   EARLY_ADOPTER        0.835001              0    53421.308753
#      (0, 2)        LAGGARDS        0.441434             38     4007.321400
#      (4, 1)   LATE_MAJORITY        0.497234             41     2097.481306
# ...                     ...             ...            ...             ...
# 240  (2, 3)   LATE_MAJORITY        0.425954             38    18358.396598
#      (2, 1)        LAGGARDS        0.388749             70     1327.358762
#      (0, 4)   LATE_MAJORITY        0.425954             24    83812.500000
#      (3, 0)        LAGGARDS        0.388749             64    83812.500000
#      (3, 3)   EARLY_ADOPTER        0.742027              0    75175.784493
#
# [6000 rows x 4 columns]
#                   Type Agent  Belangstelling  leeftijd auto  Vermogen Agent
# Step AgentID
# 1    (4, 3)    LATE_MAJORITY          0.4106             52    21244.227345
#      (2, 3)   EARLY_MAJORITY          0.5296              0      459.587673
#      (0, 0)        INNOVATOR          0.7564             59    48786.507185
#      (2, 4)         LAGGARDS          0.3774             13    83812.500000
#      (4, 4)   EARLY_MAJORITY          0.5296              4      405.824978
# ...                      ...             ...            ...             ...
# 240  (1, 0)   EARLY_MAJORITY          0.6360             46    21349.959379
#      (0, 3)         LAGGARDS          0.4420              0    47615.604983
#      (4, 3)    LATE_MAJORITY          0.4980             52    21244.227345
#      (1, 1)    EARLY_ADOPTER          0.8360             11     -187.500000
#      (0, 0)        INNOVATOR          0.8780             59    48786.507185
#
# [6000 rows x 4 columns]
#                   Type Agent  Belangstelling  leeftijd auto  Vermogen Agent
# Step AgentID
# 1    (0, 3)    EARLY_ADOPTER          0.7310              0    83812.500000
#      (2, 4)    LATE_MAJORITY          0.4175              0    42647.736300
#      (0, 1)         LAGGARDS          0.3825             37     4001.285688
#      (0, 0)        INNOVATOR          0.7660             36     6005.248351
#      (2, 1)   EARLY_MAJORITY          0.5380             56      438.363334
# ...                      ...             ...            ...             ...
# 240  (0, 2)    EARLY_ADOPTER          0.8360             44    44581.714397
#      (1, 2)    EARLY_ADOPTER          0.8360             61     -187.500000
#      (4, 0)   EARLY_MAJORITY          0.6360             70    23959.578027
#      (2, 1)   EARLY_MAJORITY          0.6360             56      438.363334
#      (2, 4)    LATE_MAJORITY          0.4980              0    42647.736300
#
# [6000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# Plot instellingen
plt.figure(figsize=(10, 6))

# Lijnen tekenen voor elk model
plt.plot(model_data1['Aantal gekochte EV'], label='Model 1')
plt.plot(model_data2['Aantal gekochte EV'], label='Model 2')
plt.plot(model_data3['Aantal gekochte EV'], label='Model 3')

# Grafiek aankleden
plt.title('Verkoop van EV over tijd')
plt.xlabel('Tijd (stappen)')
plt.ylabel('Aantal gekochte EVs')
plt.legend()  # Voegt de legenda toe
plt.grid(True)

# Toon de grafiek
plt.show()
