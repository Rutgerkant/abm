# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

model1 = BaseModelSub()


for i in range(1):
    model1.step()

print("1 stap gelukt")


model1 = SubsidieModel()
model2 = SubsidieModel2()
model3 = SubsidieModel3()


for i in range(240):
    model1.step()
    model2.step()
    model3.step()

model_data1 = model1.datacollector.get_model_vars_dataframe()
model_data2 = model2.datacollector.get_model_vars_dataframe()
model_data3 = model3.datacollector.get_model_vars_dataframe()


print(model_data1)
print(model_data2)
print(model_data3)
# Out:
# 83812.5
# 1 stap gelukt
# Stap 2 gelukt
# <function percentage_evs at 0x7f88b15aa670>
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.590436                  92                   13
# 1                     0.590436                 140                   20
# 2                     0.590436                 162                   27
# 3                     0.590436                 186                   32
# 4                     0.590436                 206                   37
# ..                         ...                 ...                  ...
# 235                   0.514935                 652                  319
# 236                   0.514935                 652                  319
# 237                   0.514935                 652                  321
# 238                   0.514935                 652                  321
# 239                   0.513229                 652                  321
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                  0.7468                     0.049277
# 1                                  0.7468                     0.127477
# 2                                  0.7468                     0.168184
# 3                                  0.7468                     0.212105
# 4                                  0.7468                     0.249598
# ..                                    ...                          ...
# 235                                0.7468                     0.950187
# 236                                0.7468                     0.950187
# 237                                0.7468                     0.950187
# 238                                0.7468                     0.950187
# 239                                0.7468                     0.950187
#
#      Hoeveelheid Subsidie
# 0             3966.687000
# 1             3966.687000
# 2             3966.687000
# 3             3966.687000
# 4             3966.687000
# ..                    ...
# 235            936.066496
# 236            936.066496
# 237            936.066496
# 238            936.066496
# 239            867.561599
#
# [240 rows x 6 columns]
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.496598                  49                   21
# 1                     0.496598                  83                   30
# 2                     0.496598                 116                   38
# 3                     0.496598                 141                   44
# 4                     0.496598                 153                   57
# ..                         ...                 ...                  ...
# 235                   0.591266                 563                  368
# 236                   0.591266                 563                  368
# 237                   0.591266                 563                  370
# 238                   0.591266                 563                  370
# 239                   0.591266                 563                  370
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                  0.7468                     0.075522
# 1                                  0.7468                     0.145688
# 2                                  0.7468                     0.185860
# 3                                  0.7468                     0.225495
# 4                                  0.7468                     0.256026
# ..                                    ...                          ...
# 235                                0.7468                     0.950187
# 236                                0.7468                     0.950187
# 237                                0.7468                     0.950187
# 238                                0.7468                     0.950187
# 239                                0.7468                     0.950187
#
#      Hoeveelheid Subsidie
# 0                     200
# 1                     200
# 2                     200
# 3                     200
# 4                     200
# ..                    ...
# 235                  4000
# 236                  4000
# 237                  4000
# 238                  4000
# 239                  4000
#
# [240 rows x 6 columns]
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.504072                  49                   11
# 1                     0.504072                  69                   23
# 2                     0.504072                  94                   30
# 3                     0.504072                 119                   44
# 4                     0.504072                 133                   55
# ..                         ...                 ...                  ...
# 235                   0.591266                 559                  430
# 236                   0.591266                 559                  430
# 237                   0.591266                 559                  432
# 238                   0.591266                 559                  432
# 239                   0.591266                 559                  433
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                  0.7468                     0.101768
# 1                                  0.7468                     0.156401
# 2                                  0.7468                     0.199250
# 3                                  0.7468                     0.238886
# 4                                  0.7468                     0.263524
# ..                                    ...                          ...
# 235                                0.7468                     0.950187
# 236                                0.7468                     0.950187
# 237                                0.7468                     0.950187
# 238                                0.7468                     0.950187
# 239                                0.7468                     0.950187
#
#      Hoeveelheid Subsidie
# 0                   500.0
# 1                   500.0
# 2                   500.0
# 3                   500.0
# 4                   500.0
# ..                    ...
# 235                4000.0
# 236                4000.0
# 237                4000.0
# 238                4000.0
# 239                4000.0
#
# [240 rows x 6 columns]

# %%
print(vars(model1.schedule.agents[0]))
print(vars(model2.schedule.agents[0]))
print(vars(model3.schedule.agents[0]))
# Out:
# {'unique_id': (0, 0), 'model': <BaseModel.BaseModelSub object at 0x7f8890015250>, 'pos': (0, 0), 'agent_type': <TypeAdopter.EARLY_ADOPTER: 1>, 'bezit_auto': True, 'bezit_EV': True, 'vermogen': 274539.7935419914, 'inkomen': 375.0, 'belangstelling': 0.836, 'leeftijd_auto': 644}
# {'unique_id': (0, 0), 'model': <BaseModel.BaseModelSub object at 0x7f8890015250>, 'pos': (0, 0), 'agent_type': <TypeAdopter.EARLY_ADOPTER: 1>, 'bezit_auto': True, 'bezit_EV': True, 'vermogen': 274539.7935419914, 'inkomen': 375.0, 'belangstelling': 0.836, 'leeftijd_auto': 644}
# {'unique_id': (0, 0), 'model': <BaseModel.BaseModelSub object at 0x7f8890015250>, 'pos': (0, 0), 'agent_type': <TypeAdopter.EARLY_ADOPTER: 1>, 'bezit_auto': True, 'bezit_EV': True, 'vermogen': 274539.7935419914, 'inkomen': 375.0, 'belangstelling': 0.836, 'leeftijd_auto': 644}

# %%
import matplotlib.pyplot as plt

# Plot instellingen
plt.figure(figsize=(10, 6))

# Lijnen tekenen voor elk model
plt.plot(model_data1['Aantal gekochte EV'], label='Model 1')
plt.plot(model_data2['Aantal gekochte EV'], label='Model 2')
plt.plot(model_data3['Aantal gekochte EV'], label='Model 3')

# Grafiek aankleden
plt.title('Verkoop van EV over tijd')
plt.xlabel('Tijd (stappen)')
plt.ylabel('Aantal verkochte EVs')
plt.legend()  # Voegt de legenda toe
plt.grid(True)

# Toon de grafiek
plt.show()
