# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

import random
import numpy as np



base_model = BaseModelSub()


for i in range(1):
    base_model.step()

print("1 stap gelukt")


# Seed doorgeven aan elk model
model1 = SubsidieModel()
model2 = SubsidieModel2()
model3 = SubsidieModel3()


for i in range(240):
    model1.step()
    model2.step()
    model3.step()
# Out:
# 83812.5
# 1 stap gelukt
# Stap 10
# Total Evs, Total cars(2, 83)
# 2
# Stap, totale hoeveelheid subsidie 1, 7933.374
# Total Evs, Total cars(2, 83)
# 5
# Stap, totale hoeveelheid subsidie 1, 1000
# 3
# Stap, totale hoeveelheid subsidie 1, 1500.0
# Total Evs, Total cars(3, 83)
# 3
# Stap, totale hoeveelheid subsidie 2, 11900.061
# Total Evs, Total cars(3, 83)
# 7
# Stap, totale hoeveelheid subsidie 2, 1400
# 7
# Stap, totale hoeveelheid subsidie 2, 3500.0
# Total Evs, Total cars(9, 83)
# 9
# Stap, totale hoeveelheid subsidie 3, 35700.18299999999
# Total Evs, Total cars(9, 83)
# 8
# Stap, totale hoeveelheid subsidie 3, 1600
# 7
# Stap, totale hoeveelheid subsidie 3, 3500.0
# Total Evs, Total cars(11, 83)
# 11
# Stap, totale hoeveelheid subsidie 4, 43633.556999999986
# Total Evs, Total cars(11, 83)
# 9
# Stap, totale hoeveelheid subsidie 4, 1800
# 9
# Stap, totale hoeveelheid subsidie 4, 4500.0
# Total Evs, Total cars(12, 83)
# 12
# Stap, totale hoeveelheid subsidie 5, 47600.243999999984
# Total Evs, Total cars(12, 83)
# 11
# Stap, totale hoeveelheid subsidie 5, 2200
# 12
# Stap, totale hoeveelheid subsidie 5, 6000.0
# Total Evs, Total cars(12, 83)
# 12
# Stap, totale hoeveelheid subsidie 6, 47600.243999999984
# Total Evs, Total cars(12, 83)
# 11
# Stap, totale hoeveelheid subsidie 6, 2200
# 14
# Stap, totale hoeveelheid subsidie 6, 7000.0
# Total Evs, Total cars(13, 83)
# 13
# Stap, totale hoeveelheid subsidie 7, 51566.93099999998
# Total Evs, Total cars(13, 83)
# 11
# Stap, totale hoeveelheid subsidie 7, 2200
# 16
# Stap, totale hoeveelheid subsidie 7, 8000.0
# Total Evs, Total cars(15, 83)
# 15
# Stap, totale hoeveelheid subsidie 8, 59500.30499999998
# Total Evs, Total cars(15, 83)
# 12
# Stap, totale hoeveelheid subsidie 8, 2400
# 19
# Stap, totale hoeveelheid subsidie 8, 9500.0
# Total Evs, Total cars(16, 83)
# 16
# Stap, totale hoeveelheid subsidie 9, 63466.99199999998
# Total Evs, Total cars(16, 83)
# 14
# Stap, totale hoeveelheid subsidie 9, 2800
# 19
# Stap, totale hoeveelheid subsidie 9, 9500.0
# Total Evs, Total cars(17, 83)
# 17
# Stap, totale hoeveelheid subsidie 10, 67433.67899999997
# Total Evs, Total cars(17, 83)
# 14
# Stap, totale hoeveelheid subsidie 10, 2800
# 20
# Stap, totale hoeveelheid subsidie 10, 10000.0
# Total Evs, Total cars(18, 83)
# 18
# Stap, totale hoeveelheid subsidie 11, 71400.36599999998
# Total Evs, Total cars(18, 83)
# 14
# Stap, totale hoeveelheid subsidie 11, 2800
# 21
# Stap, totale hoeveelheid subsidie 11, 10500.0
# Total Evs, Total cars(19, 83)
# 19
# Stap, totale hoeveelheid subsidie 12, 75076.7557979484
# Total Evs, Total cars(19, 83)
# 18
# Stap, totale hoeveelheid subsidie 12, 4400
# 21
# Stap, totale hoeveelheid subsidie 12, 10500.0
# Total Evs, Total cars(19, 83)
# 19
# Stap, totale hoeveelheid subsidie 13, 75076.7557979484
# Total Evs, Total cars(19, 83)
# 19
# Stap, totale hoeveelheid subsidie 13, 4800
# 22
# Stap, totale hoeveelheid subsidie 13, 11069.41419166231
# Total Evs, Total cars(20, 83)
# 20
# Stap, totale hoeveelheid subsidie 14, 78753.14559589681
# Total Evs, Total cars(20, 83)
# 19
# Stap, totale hoeveelheid subsidie 14, 4800
# 22
# Stap, totale hoeveelheid subsidie 14, 11069.41419166231
# Total Evs, Total cars(21, 83)
# 21
# Stap, totale hoeveelheid subsidie 15, 82429.53539384523
# Total Evs, Total cars(21, 83)
# 19
# Stap, totale hoeveelheid subsidie 15, 4800
# 23
# Stap, totale hoeveelheid subsidie 15, 11638.82838332462
# Total Evs, Total cars(21, 83)
# 21
# Stap, totale hoeveelheid subsidie 16, 82429.53539384523
# Total Evs, Total cars(21, 83)
# 19
# Stap, totale hoeveelheid subsidie 16, 4800
# 23
# Stap, totale hoeveelheid subsidie 16, 11638.82838332462
# Total Evs, Total cars(22, 83)
# 22
# Stap, totale hoeveelheid subsidie 17, 86105.92519179365
# Total Evs, Total cars(22, 83)
# 19
# Stap, totale hoeveelheid subsidie 17, 4800
# 23
# Stap, totale hoeveelheid subsidie 17, 11638.82838332462
# Total Evs, Total cars(22, 83)
# 22
# Stap, totale hoeveelheid subsidie 18, 86105.92519179365
# Total Evs, Total cars(22, 83)
# 19
# Stap, totale hoeveelheid subsidie 18, 4800
# 23
# Stap, totale hoeveelheid subsidie 18, 11638.82838332462
# Total Evs, Total cars(23, 83)
# 23
# Stap, totale hoeveelheid subsidie 19, 89782.31498974207
# Total Evs, Total cars(23, 83)
# 19
# Stap, totale hoeveelheid subsidie 19, 4800
# 23
# Stap, totale hoeveelheid subsidie 19, 11638.82838332462
# Total Evs, Total cars(23, 83)
# 23
# Stap, totale hoeveelheid subsidie 20, 89782.31498974207
# Total Evs, Total cars(23, 83)
# 19
# Stap, totale hoeveelheid subsidie 20, 4800
# 23
# Stap, totale hoeveelheid subsidie 20, 11638.82838332462
# Total Evs, Total cars(23, 83)
# 23
# Stap, totale hoeveelheid subsidie 21, 89782.31498974207
# Total Evs, Total cars(23, 83)
# 19
# Stap, totale hoeveelheid subsidie 21, 4800
# 23
# Stap, totale hoeveelheid subsidie 21, 11638.82838332462
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 22, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 22, 4800
# 23
# Stap, totale hoeveelheid subsidie 22, 11638.82838332462
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 23, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 23, 4800
# 25
# Stap, totale hoeveelheid subsidie 23, 12777.656766649241
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 24, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 24, 4800
# 25
# Stap, totale hoeveelheid subsidie 24, 12777.656766649241
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 25, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 25, 4800
# 25
# Stap, totale hoeveelheid subsidie 25, 12777.656766649241
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 26, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 26, 4800
# 26
# Stap, totale hoeveelheid subsidie 26, 13426.121809982127
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 27, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 27, 4800
# 26
# Stap, totale hoeveelheid subsidie 27, 13426.121809982127
# Total Evs, Total cars(24, 83)
# 24
# Stap, totale hoeveelheid subsidie 28, 93458.70478769048
# Total Evs, Total cars(24, 83)
# 19
# Stap, totale hoeveelheid subsidie 28, 4800
# 26
# Stap, totale hoeveelheid subsidie 28, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 29, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 19
# Stap, totale hoeveelheid subsidie 29, 4800
# 26
# Stap, totale hoeveelheid subsidie 29, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 30, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 19
# Stap, totale hoeveelheid subsidie 30, 4800
# 26
# Stap, totale hoeveelheid subsidie 30, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 31, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 19
# Stap, totale hoeveelheid subsidie 31, 4800
# 26
# Stap, totale hoeveelheid subsidie 31, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 32, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 20
# Stap, totale hoeveelheid subsidie 32, 5400
# 26
# Stap, totale hoeveelheid subsidie 32, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 33, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 20
# Stap, totale hoeveelheid subsidie 33, 5400
# 26
# Stap, totale hoeveelheid subsidie 33, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 34, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 20
# Stap, totale hoeveelheid subsidie 34, 5400
# 26
# Stap, totale hoeveelheid subsidie 34, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 35, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 20
# Stap, totale hoeveelheid subsidie 35, 5400
# 26
# Stap, totale hoeveelheid subsidie 35, 13426.121809982127
# Total Evs, Total cars(25, 83)
# 25
# Stap, totale hoeveelheid subsidie 36, 96866.04243405865
# Total Evs, Total cars(25, 83)
# 20
# Stap, totale hoeveelheid subsidie 36, 5400
# 26
# Stap, totale hoeveelheid subsidie 36, 13426.121809982127
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 37, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 20
# Stap, totale hoeveelheid subsidie 37, 5400
# 27
# Stap, totale hoeveelheid subsidie 37, 14164.612206923448
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 38, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 20
# Stap, totale hoeveelheid subsidie 38, 5400
# 27
# Stap, totale hoeveelheid subsidie 38, 14164.612206923448
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 39, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 20
# Stap, totale hoeveelheid subsidie 39, 5400
# 27
# Stap, totale hoeveelheid subsidie 39, 14164.612206923448
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 40, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 20
# Stap, totale hoeveelheid subsidie 40, 5400
# 28
# Stap, totale hoeveelheid subsidie 40, 14903.102603864769
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 41, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 21
# Stap, totale hoeveelheid subsidie 41, 6200
# 29
# Stap, totale hoeveelheid subsidie 41, 15641.59300080609
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 42, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 21
# Stap, totale hoeveelheid subsidie 42, 6200
# 29
# Stap, totale hoeveelheid subsidie 42, 15641.59300080609
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 43, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 21
# Stap, totale hoeveelheid subsidie 43, 6200
# 29
# Stap, totale hoeveelheid subsidie 43, 15641.59300080609
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 44, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 21
# Stap, totale hoeveelheid subsidie 44, 6200
# 30
# Stap, totale hoeveelheid subsidie 44, 16380.08339774741
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 45, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 21
# Stap, totale hoeveelheid subsidie 45, 6200
# 30
# Stap, totale hoeveelheid subsidie 45, 16380.08339774741
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 46, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 22
# Stap, totale hoeveelheid subsidie 46, 7000
# 31
# Stap, totale hoeveelheid subsidie 46, 17118.57379468873
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 47, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 22
# Stap, totale hoeveelheid subsidie 47, 7000
# 31
# Stap, totale hoeveelheid subsidie 47, 17118.57379468873
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 48, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 22
# Stap, totale hoeveelheid subsidie 48, 7000
# 31
# Stap, totale hoeveelheid subsidie 48, 17118.57379468873
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 49, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 22
# Stap, totale hoeveelheid subsidie 49, 7000
# 31
# Stap, totale hoeveelheid subsidie 49, 17118.57379468873
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 50, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 23
# Stap, totale hoeveelheid subsidie 50, 8000
# 31
# Stap, totale hoeveelheid subsidie 50, 17118.57379468873
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 51, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 24
# Stap, totale hoeveelheid subsidie 51, 9000
# 32
# Stap, totale hoeveelheid subsidie 51, 17959.587619538175
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 52, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 24
# Stap, totale hoeveelheid subsidie 52, 9000
# 33
# Stap, totale hoeveelheid subsidie 52, 18800.60144438762
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 53, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 24
# Stap, totale hoeveelheid subsidie 53, 9000
# 33
# Stap, totale hoeveelheid subsidie 53, 18800.60144438762
# Total Evs, Total cars(26, 83)
# 26
# Stap, totale hoeveelheid subsidie 54, 100024.01818593257
# Total Evs, Total cars(26, 83)
# 25
# Stap, totale hoeveelheid subsidie 54, 10000
# 33
# Stap, totale hoeveelheid subsidie 54, 18800.60144438762
# Total Evs, Total cars(28, 83)
# 28
# Stap, totale hoeveelheid subsidie 55, 105877.74439944915
# Total Evs, Total cars(28, 83)
# 25
# Stap, totale hoeveelheid subsidie 55, 10000
# 34
# Stap, totale hoeveelheid subsidie 55, 19641.615269237063
# Total Evs, Total cars(28, 83)
# 28
# Stap, totale hoeveelheid subsidie 56, 105877.74439944915
# Total Evs, Total cars(28, 83)
# 25
# Stap, totale hoeveelheid subsidie 56, 10000
# 35
# Stap, totale hoeveelheid subsidie 56, 20482.629094086507
# Total Evs, Total cars(29, 83)
# 29
# Stap, totale hoeveelheid subsidie 57, 108804.60750620744
# Total Evs, Total cars(29, 83)
# 25
# Stap, totale hoeveelheid subsidie 57, 10000
# 35
# Stap, totale hoeveelheid subsidie 57, 20482.629094086507
# Total Evs, Total cars(30, 83)
# 30
# Stap, totale hoeveelheid subsidie 58, 111731.47061296573
# Total Evs, Total cars(30, 83)
# /Users/michielvanhouten/Dropbox/Mac/Documents/GitHub/abm/.venv/lib/python3.9/site-packages/mesa/time.py:82: FutureWarning: The AgentSet is experimental. It may be changed or removed in any and all future releases, including patch releases.
# We would love to hear what you think about this new feature. If you have any thoughts, share them with us here: https://github.com/projectmesa/mesa/discussions/1919
#   self._agents: AgentSet = AgentSet(agents, model)
# 25
# Stap, totale hoeveelheid subsidie 58, 10000
# 36
# Stap, totale hoeveelheid subsidie 58, 21323.64291893595
# Total Evs, Total cars(30, 83)
# 30
# Stap, totale hoeveelheid subsidie 59, 111731.47061296573
# Total Evs, Total cars(30, 83)
# 25
# Stap, totale hoeveelheid subsidie 59, 10000
# 37
# Stap, totale hoeveelheid subsidie 59, 22164.656743785396
# Total Evs, Total cars(31, 83)
# 31
# Stap, totale hoeveelheid subsidie 60, 114444.13477469006
# Total Evs, Total cars(31, 83)
# 25
# Stap, totale hoeveelheid subsidie 60, 10000
# 37
# Stap, totale hoeveelheid subsidie 60, 22164.656743785396
# Total Evs, Total cars(33, 83)
# 33
# Stap, totale hoeveelheid subsidie 61, 119869.46309813872
# Total Evs, Total cars(33, 83)
# 25
# Stap, totale hoeveelheid subsidie 61, 10000
# 37
# Stap, totale hoeveelheid subsidie 61, 22164.656743785396
# Total Evs, Total cars(33, 83)
# 33
# Stap, totale hoeveelheid subsidie 62, 119869.46309813872
# Total Evs, Total cars(33, 83)
# 25
# Stap, totale hoeveelheid subsidie 62, 10000
# 37
# Stap, totale hoeveelheid subsidie 62, 22164.656743785396
# Total Evs, Total cars(34, 83)
# 34
# Stap, totale hoeveelheid subsidie 63, 122582.12725986305
# Total Evs, Total cars(34, 83)
# 26
# Stap, totale hoeveelheid subsidie 63, 11200
# 37
# Stap, totale hoeveelheid subsidie 63, 22164.656743785396
# Total Evs, Total cars(34, 83)
# 34
# Stap, totale hoeveelheid subsidie 64, 122582.12725986305
# Total Evs, Total cars(34, 83)
# 26
# Stap, totale hoeveelheid subsidie 64, 11200
# 37
# Stap, totale hoeveelheid subsidie 64, 22164.656743785396
# Total Evs, Total cars(35, 83)
# 35
# Stap, totale hoeveelheid subsidie 65, 125294.79142158738
# Total Evs, Total cars(35, 83)
# 27
# Stap, totale hoeveelheid subsidie 65, 12400
# 37
# Stap, totale hoeveelheid subsidie 65, 22164.656743785396
# Total Evs, Total cars(35, 83)
# 35
# Stap, totale hoeveelheid subsidie 66, 125294.79142158738
# Total Evs, Total cars(35, 83)
# 27
# Stap, totale hoeveelheid subsidie 66, 12400
# 37
# Stap, totale hoeveelheid subsidie 66, 22164.656743785396
# Total Evs, Total cars(35, 83)
# 35
# Stap, totale hoeveelheid subsidie 67, 125294.79142158738
# Total Evs, Total cars(35, 83)
# 27
# Stap, totale hoeveelheid subsidie 67, 12400
# 37
# Stap, totale hoeveelheid subsidie 67, 22164.656743785396
# Total Evs, Total cars(35, 83)
# 35
# Stap, totale hoeveelheid subsidie 68, 125294.79142158738
# Total Evs, Total cars(35, 83)
# 27
# Stap, totale hoeveelheid subsidie 68, 12400
# 37
# Stap, totale hoeveelheid subsidie 68, 22164.656743785396
# Total Evs, Total cars(36, 83)
# 36
# Stap, totale hoeveelheid subsidie 69, 128007.4555833117
# Total Evs, Total cars(36, 83)
# 27
# Stap, totale hoeveelheid subsidie 69, 12400
# 37
# Stap, totale hoeveelheid subsidie 69, 22164.656743785396
# Total Evs, Total cars(37, 83)
# 37
# Stap, totale hoeveelheid subsidie 70, 130720.11974503603
# Total Evs, Total cars(37, 83)
# 27
# Stap, totale hoeveelheid subsidie 70, 12400
# 37
# Stap, totale hoeveelheid subsidie 70, 22164.656743785396
# Total Evs, Total cars(39, 83)
# 39
# Stap, totale hoeveelheid subsidie 71, 136145.4480684847
# Total Evs, Total cars(39, 83)
# 28
# Stap, totale hoeveelheid subsidie 71, 13600
# 37
# Stap, totale hoeveelheid subsidie 71, 22164.656743785396
# Total Evs, Total cars(39, 83)
# 39
# Stap, totale hoeveelheid subsidie 72, 136145.4480684847
# Total Evs, Total cars(39, 83)
# 28
# Stap, totale hoeveelheid subsidie 72, 13600
# 37
# Stap, totale hoeveelheid subsidie 72, 22164.656743785396
# Total Evs, Total cars(40, 83)
# 40
# Stap, totale hoeveelheid subsidie 73, 138659.58917652362
# Total Evs, Total cars(40, 83)
# 30
# Stap, totale hoeveelheid subsidie 73, 16400
# 37
# Stap, totale hoeveelheid subsidie 73, 22164.656743785396
# Total Evs, Total cars(40, 83)
# 40
# Stap, totale hoeveelheid subsidie 74, 138659.58917652362
# Total Evs, Total cars(40, 83)
# 30
# Stap, totale hoeveelheid subsidie 74, 16400
# 38
# Stap, totale hoeveelheid subsidie 74, 23255.392876534497
# Total Evs, Total cars(40, 83)
# 40
# Stap, totale hoeveelheid subsidie 75, 138659.58917652362
# Total Evs, Total cars(40, 83)
# 30
# Stap, totale hoeveelheid subsidie 75, 16400
# 38
# Stap, totale hoeveelheid subsidie 75, 23255.392876534497
# Total Evs, Total cars(40, 83)
# 40
# Stap, totale hoeveelheid subsidie 76, 138659.58917652362
# Total Evs, Total cars(40, 83)
# 31
# Stap, totale hoeveelheid subsidie 76, 17800
# 39
# Stap, totale hoeveelheid subsidie 76, 24346.1290092836
# Total Evs, Total cars(40, 83)
# 40
# Stap, totale hoeveelheid subsidie 77, 138659.58917652362
# Total Evs, Total cars(40, 83)
# 32
# Stap, totale hoeveelheid subsidie 77, 19200
# 39
# Stap, totale hoeveelheid subsidie 77, 24346.1290092836
# Total Evs, Total cars(42, 83)
# 42
# Stap, totale hoeveelheid subsidie 78, 143687.87139260146
# Total Evs, Total cars(42, 83)
# 32
# Stap, totale hoeveelheid subsidie 78, 19200
# 40
# Stap, totale hoeveelheid subsidie 78, 25436.8651420327
# Total Evs, Total cars(42, 83)
# 42
# Stap, totale hoeveelheid subsidie 79, 143687.87139260146
# Total Evs, Total cars(42, 83)
# 33
# Stap, totale hoeveelheid subsidie 79, 20600
# 42
# Stap, totale hoeveelheid subsidie 79, 27618.337407530904
# Total Evs, Total cars(42, 83)
# 42
# Stap, totale hoeveelheid subsidie 80, 143687.87139260146
# Total Evs, Total cars(42, 83)
# 33
# Stap, totale hoeveelheid subsidie 80, 20600
# 42
# Stap, totale hoeveelheid subsidie 80, 27618.337407530904
# Total Evs, Total cars(43, 83)
# 43
# Stap, totale hoeveelheid subsidie 81, 146202.01250064038
# Total Evs, Total cars(43, 83)
# 34
# Stap, totale hoeveelheid subsidie 81, 22000
# 42
# Stap, totale hoeveelheid subsidie 81, 27618.337407530904
# Total Evs, Total cars(43, 83)
# 43
# Stap, totale hoeveelheid subsidie 82, 146202.01250064038
# Total Evs, Total cars(43, 83)
# 34
# Stap, totale hoeveelheid subsidie 82, 22000
# 43
# Stap, totale hoeveelheid subsidie 82, 28709.073540280006
# Total Evs, Total cars(43, 83)
# 43
# Stap, totale hoeveelheid subsidie 83, 146202.01250064038
# Total Evs, Total cars(43, 83)
# 35
# Stap, totale hoeveelheid subsidie 83, 23400
# 43
# Stap, totale hoeveelheid subsidie 83, 28709.073540280006
# Total Evs, Total cars(43, 83)
# 43
# Stap, totale hoeveelheid subsidie 84, 146202.01250064038
# Total Evs, Total cars(43, 83)
# 35
# Stap, totale hoeveelheid subsidie 84, 23400
# 44
# Stap, totale hoeveelheid subsidie 84, 29951.234806972414
# Total Evs, Total cars(44, 83)
# 44
# Stap, totale hoeveelheid subsidie 85, 148532.15922514803
# Total Evs, Total cars(44, 83)
# 35
# Stap, totale hoeveelheid subsidie 85, 23400
# 44
# Stap, totale hoeveelheid subsidie 85, 29951.234806972414
# Total Evs, Total cars(44, 83)
# 44
# Stap, totale hoeveelheid subsidie 86, 148532.15922514803
# Total Evs, Total cars(44, 83)
# 35
# Stap, totale hoeveelheid subsidie 86, 23400
# 44
# Stap, totale hoeveelheid subsidie 86, 29951.234806972414
# Total Evs, Total cars(44, 83)
# 44
# Stap, totale hoeveelheid subsidie 87, 148532.15922514803
# Total Evs, Total cars(44, 83)
# 35
# Stap, totale hoeveelheid subsidie 87, 23400
# 44
# Stap, totale hoeveelheid subsidie 87, 29951.234806972414
# Total Evs, Total cars(44, 83)
# 44
# Stap, totale hoeveelheid subsidie 88, 148532.15922514803
# Total Evs, Total cars(44, 83)
# 35
# Stap, totale hoeveelheid subsidie 88, 23400
# 44
# Stap, totale hoeveelheid subsidie 88, 29951.234806972414
# Total Evs, Total cars(44, 83)
# 44
# Stap, totale hoeveelheid subsidie 89, 148532.15922514803
# Total Evs, Total cars(44, 83)
# 35
# Stap, totale hoeveelheid subsidie 89, 23400
# 44
# Stap, totale hoeveelheid subsidie 89, 29951.234806972414
# Total Evs, Total cars(44, 83)
# 44
# Stap, totale hoeveelheid subsidie 90, 148532.15922514803
# Total Evs, Total cars(44, 83)
# 35
# Stap, totale hoeveelheid subsidie 90, 23400
# 44
# Stap, totale hoeveelheid subsidie 90, 29951.234806972414
# Total Evs, Total cars(45, 83)
# 45
# Stap, totale hoeveelheid subsidie 91, 150862.30594965568
# Total Evs, Total cars(45, 83)
# 35
# Stap, totale hoeveelheid subsidie 91, 23400
# 44
# Stap, totale hoeveelheid subsidie 91, 29951.234806972414
# Total Evs, Total cars(46, 83)
# 46
# Stap, totale hoeveelheid subsidie 92, 153192.45267416333
# Total Evs, Total cars(46, 83)
# 35
# Stap, totale hoeveelheid subsidie 92, 23400
# 44
# Stap, totale hoeveelheid subsidie 92, 29951.234806972414
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 93, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 36
# Stap, totale hoeveelheid subsidie 93, 25000
# 44
# Stap, totale hoeveelheid subsidie 93, 29951.234806972414
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 94, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 36
# Stap, totale hoeveelheid subsidie 94, 25000
# 44
# Stap, totale hoeveelheid subsidie 94, 29951.234806972414
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 95, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 36
# Stap, totale hoeveelheid subsidie 95, 25000
# 44
# Stap, totale hoeveelheid subsidie 95, 29951.234806972414
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 96, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 37
# Stap, totale hoeveelheid subsidie 96, 26800
# 45
# Stap, totale hoeveelheid subsidie 96, 31365.843314148195
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 97, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 37
# Stap, totale hoeveelheid subsidie 97, 26800
# 45
# Stap, totale hoeveelheid subsidie 97, 31365.843314148195
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 98, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 38
# Stap, totale hoeveelheid subsidie 98, 28600
# 46
# Stap, totale hoeveelheid subsidie 98, 32780.45182132397
# Total Evs, Total cars(47, 83)
# 47
# Stap, totale hoeveelheid subsidie 99, 155522.59939867098
# Total Evs, Total cars(47, 83)
# 38
# Stap, totale hoeveelheid subsidie 99, 28600
# 46
# Stap, totale hoeveelheid subsidie 99, 32780.45182132397
# Total Evs, Total cars(48, 83)
# 48
# Stap, totale hoeveelheid subsidie 100, 157682.21714660592
# Total Evs, Total cars(48, 83)
# 38
# Stap, totale hoeveelheid subsidie 100, 28600
# 46
# Stap, totale hoeveelheid subsidie 100, 32780.45182132397
# Total Evs, Total cars(48, 83)
# 48
# Stap, totale hoeveelheid subsidie 101, 157682.21714660592
# Total Evs, Total cars(48, 83)
# 40
# Stap, totale hoeveelheid subsidie 101, 32200
# 47
# Stap, totale hoeveelheid subsidie 101, 34195.06032849975
# Total Evs, Total cars(48, 83)
# 48
# Stap, totale hoeveelheid subsidie 102, 157682.21714660592
# Total Evs, Total cars(48, 83)
# 40
# Stap, totale hoeveelheid subsidie 102, 32200
# 48
# Stap, totale hoeveelheid subsidie 102, 35609.668835675526
# Total Evs, Total cars(48, 83)
# 48
# Stap, totale hoeveelheid subsidie 103, 157682.21714660592
# Total Evs, Total cars(48, 83)
# 40
# Stap, totale hoeveelheid subsidie 103, 32200
# 48
# Stap, totale hoeveelheid subsidie 103, 35609.668835675526
# Total Evs, Total cars(48, 83)
# 48
# Stap, totale hoeveelheid subsidie 104, 157682.21714660592
# Total Evs, Total cars(48, 83)
# 40
# Stap, totale hoeveelheid subsidie 104, 32200
# 48
# Stap, totale hoeveelheid subsidie 104, 35609.668835675526
# Total Evs, Total cars(48, 83)
# 48
# Stap, totale hoeveelheid subsidie 105, 157682.21714660592
# Total Evs, Total cars(48, 83)
# 40
# Stap, totale hoeveelheid subsidie 105, 32200
# 49
# Stap, totale hoeveelheid subsidie 105, 37024.2773428513
# Total Evs, Total cars(49, 83)
# 49
# Stap, totale hoeveelheid subsidie 106, 159841.83489454087
# Total Evs, Total cars(49, 83)
# 40
# Stap, totale hoeveelheid subsidie 106, 32200
# 49
# Stap, totale hoeveelheid subsidie 106, 37024.2773428513
# Total Evs, Total cars(49, 83)
# 49
# Stap, totale hoeveelheid subsidie 107, 159841.83489454087
# Total Evs, Total cars(49, 83)
# 41
# Stap, totale hoeveelheid subsidie 107, 34000
# 49
# Stap, totale hoeveelheid subsidie 107, 37024.2773428513
# Total Evs, Total cars(49, 83)
# 49
# Stap, totale hoeveelheid subsidie 108, 159841.83489454087
# Total Evs, Total cars(49, 83)
# 41
# Stap, totale hoeveelheid subsidie 108, 34000
# 49
# Stap, totale hoeveelheid subsidie 108, 37024.2773428513
# Total Evs, Total cars(49, 83)
# 49
# Stap, totale hoeveelheid subsidie 109, 159841.83489454087
# Total Evs, Total cars(49, 83)
# 41
# Stap, totale hoeveelheid subsidie 109, 34000
# 49
# Stap, totale hoeveelheid subsidie 109, 37024.2773428513
# Total Evs, Total cars(50, 83)
# 50
# Stap, totale hoeveelheid subsidie 110, 161843.40362330026
# Total Evs, Total cars(50, 83)
# 41
# Stap, totale hoeveelheid subsidie 110, 34000
# 49
# Stap, totale hoeveelheid subsidie 110, 37024.2773428513
# Total Evs, Total cars(50, 83)
# 50
# Stap, totale hoeveelheid subsidie 111, 161843.40362330026
# Total Evs, Total cars(50, 83)
# 42
# Stap, totale hoeveelheid subsidie 111, 36000
# 49
# Stap, totale hoeveelheid subsidie 111, 37024.2773428513
# Total Evs, Total cars(50, 83)
# 50
# Stap, totale hoeveelheid subsidie 112, 161843.40362330026
# Total Evs, Total cars(50, 83)
# 42
# Stap, totale hoeveelheid subsidie 112, 36000
# 49
# Stap, totale hoeveelheid subsidie 112, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 113, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 42
# Stap, totale hoeveelheid subsidie 113, 36000
# 49
# Stap, totale hoeveelheid subsidie 113, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 114, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 43
# Stap, totale hoeveelheid subsidie 114, 38000
# 49
# Stap, totale hoeveelheid subsidie 114, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 115, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 43
# Stap, totale hoeveelheid subsidie 115, 38000
# 49
# Stap, totale hoeveelheid subsidie 115, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 116, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 43
# Stap, totale hoeveelheid subsidie 116, 38000
# 49
# Stap, totale hoeveelheid subsidie 116, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 117, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 43
# Stap, totale hoeveelheid subsidie 117, 38000
# 49
# Stap, totale hoeveelheid subsidie 117, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 118, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 43
# Stap, totale hoeveelheid subsidie 118, 38000
# 49
# Stap, totale hoeveelheid subsidie 118, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 119, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 44
# Stap, totale hoeveelheid subsidie 119, 40000
# 49
# Stap, totale hoeveelheid subsidie 119, 37024.2773428513
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 120, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 44
# Stap, totale hoeveelheid subsidie 120, 40000
# 50
# Stap, totale hoeveelheid subsidie 120, 38858.925676660925
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 121, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 45
# Stap, totale hoeveelheid subsidie 121, 42200
# 50
# Stap, totale hoeveelheid subsidie 121, 38858.925676660925
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 122, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 45
# Stap, totale hoeveelheid subsidie 122, 42200
# 50
# Stap, totale hoeveelheid subsidie 122, 38858.925676660925
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 123, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 45
# Stap, totale hoeveelheid subsidie 123, 42200
# 52
# Stap, totale hoeveelheid subsidie 123, 42528.22234428017
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 124, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 46
# Stap, totale hoeveelheid subsidie 124, 44400
# 52
# Stap, totale hoeveelheid subsidie 124, 42528.22234428017
# Total Evs, Total cars(51, 83)
# 51
# Stap, totale hoeveelheid subsidie 125, 163844.97235205965
# Total Evs, Total cars(51, 83)
# 46
# Stap, totale hoeveelheid subsidie 125, 44400
# 52
# Stap, totale hoeveelheid subsidie 125, 42528.22234428017
# Total Evs, Total cars(52, 83)
# 52
# Stap, totale hoeveelheid subsidie 126, 165700.0586884163
# Total Evs, Total cars(52, 83)
# 46
# Stap, totale hoeveelheid subsidie 126, 44400
# 52
# Stap, totale hoeveelheid subsidie 126, 42528.22234428017
# Total Evs, Total cars(52, 83)
# 52
# Stap, totale hoeveelheid subsidie 127, 165700.0586884163
# Total Evs, Total cars(52, 83)
# 46
# Stap, totale hoeveelheid subsidie 127, 44400
# 54
# Stap, totale hoeveelheid subsidie 127, 46197.519011899414
# Total Evs, Total cars(52, 83)
# 52
# Stap, totale hoeveelheid subsidie 128, 165700.0586884163
# Total Evs, Total cars(52, 83)
# 46
# Stap, totale hoeveelheid subsidie 128, 44400
# 54
# Stap, totale hoeveelheid subsidie 128, 46197.519011899414
# Total Evs, Total cars(53, 83)
# 53
# Stap, totale hoeveelheid subsidie 129, 167555.14502477294
# Total Evs, Total cars(53, 83)
# 46
# Stap, totale hoeveelheid subsidie 129, 44400
# 54
# Stap, totale hoeveelheid subsidie 129, 46197.519011899414
# Total Evs, Total cars(55, 83)
# 55
# Stap, totale hoeveelheid subsidie 130, 171265.31769748623
# Total Evs, Total cars(55, 83)
# 47
# Stap, totale hoeveelheid subsidie 130, 46600
# 54
# Stap, totale hoeveelheid subsidie 130, 46197.519011899414
# Total Evs, Total cars(55, 83)
# 55
# Stap, totale hoeveelheid subsidie 131, 171265.31769748623
# Total Evs, Total cars(55, 83)
# 47
# Stap, totale hoeveelheid subsidie 131, 46600
# 54
# Stap, totale hoeveelheid subsidie 131, 46197.519011899414
# Total Evs, Total cars(56, 83)
# 56
# Stap, totale hoeveelheid subsidie 132, 172984.64177858844
# Total Evs, Total cars(56, 83)
# 47
# Stap, totale hoeveelheid subsidie 132, 46600
# 54
# Stap, totale hoeveelheid subsidie 132, 46197.519011899414
# Total Evs, Total cars(56, 83)
# 56
# Stap, totale hoeveelheid subsidie 133, 172984.64177858844
# Total Evs, Total cars(56, 83)
# 47
# Stap, totale hoeveelheid subsidie 133, 46600
# 55
# Stap, totale hoeveelheid subsidie 133, 48286.86860786104
# Total Evs, Total cars(56, 83)
# 56
# Stap, totale hoeveelheid subsidie 134, 172984.64177858844
# Total Evs, Total cars(56, 83)
# 47
# Stap, totale hoeveelheid subsidie 134, 46600
# 55
# Stap, totale hoeveelheid subsidie 134, 48286.86860786104
# Total Evs, Total cars(56, 83)
# 56
# Stap, totale hoeveelheid subsidie 135, 172984.64177858844
# Total Evs, Total cars(56, 83)
# 47
# Stap, totale hoeveelheid subsidie 135, 46600
# 55
# Stap, totale hoeveelheid subsidie 135, 48286.86860786104
# Total Evs, Total cars(56, 83)
# 56
# Stap, totale hoeveelheid subsidie 136, 172984.64177858844
# Total Evs, Total cars(56, 83)
# 48
# Stap, totale hoeveelheid subsidie 136, 49000
# 56
# Stap, totale hoeveelheid subsidie 136, 50376.21820382267
# Total Evs, Total cars(56, 83)
# 56
# Stap, totale hoeveelheid subsidie 137, 172984.64177858844
# Total Evs, Total cars(56, 83)
# 48
# Stap, totale hoeveelheid subsidie 137, 49000
# 56
# Stap, totale hoeveelheid subsidie 137, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 138, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 48
# Stap, totale hoeveelheid subsidie 138, 49000
# 56
# Stap, totale hoeveelheid subsidie 138, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 139, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 49
# Stap, totale hoeveelheid subsidie 139, 51400
# 56
# Stap, totale hoeveelheid subsidie 139, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 140, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 49
# Stap, totale hoeveelheid subsidie 140, 51400
# 56
# Stap, totale hoeveelheid subsidie 140, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 141, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 49
# Stap, totale hoeveelheid subsidie 141, 51400
# 56
# Stap, totale hoeveelheid subsidie 141, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 142, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 49
# Stap, totale hoeveelheid subsidie 142, 51400
# 56
# Stap, totale hoeveelheid subsidie 142, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 143, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 50
# Stap, totale hoeveelheid subsidie 143, 53800
# 56
# Stap, totale hoeveelheid subsidie 143, 50376.21820382267
# Total Evs, Total cars(57, 83)
# 57
# Stap, totale hoeveelheid subsidie 144, 174703.96585969065
# Total Evs, Total cars(57, 83)
# 50
# Stap, totale hoeveelheid subsidie 144, 53800
# 57
# Stap, totale hoeveelheid subsidie 144, 52755.62882639159
# Total Evs, Total cars(59, 83)
# 59
# Stap, totale hoeveelheid subsidie 145, 177890.96070507736
# Total Evs, Total cars(59, 83)
# 51
# Stap, totale hoeveelheid subsidie 145, 56400
# 57
# Stap, totale hoeveelheid subsidie 145, 52755.62882639159
# Total Evs, Total cars(59, 83)
# 59
# Stap, totale hoeveelheid subsidie 146, 177890.96070507736
# Total Evs, Total cars(59, 83)
# 52
# Stap, totale hoeveelheid subsidie 146, 59000
# 57
# Stap, totale hoeveelheid subsidie 146, 52755.62882639159
# Total Evs, Total cars(60, 83)
# 60
# Stap, totale hoeveelheid subsidie 147, 179484.45812777072
# Total Evs, Total cars(60, 83)
# 52
# Stap, totale hoeveelheid subsidie 147, 59000
# 57
# Stap, totale hoeveelheid subsidie 147, 52755.62882639159
# Total Evs, Total cars(60, 83)
# 60
# Stap, totale hoeveelheid subsidie 148, 179484.45812777072
# Total Evs, Total cars(60, 83)
# 52
# Stap, totale hoeveelheid subsidie 148, 59000
# 57
# Stap, totale hoeveelheid subsidie 148, 52755.62882639159
# Total Evs, Total cars(62, 83)
# 62
# Stap, totale hoeveelheid subsidie 149, 182671.45297315743
# Total Evs, Total cars(62, 83)
# 52
# Stap, totale hoeveelheid subsidie 149, 59000
# 57
# Stap, totale hoeveelheid subsidie 149, 52755.62882639159
# Total Evs, Total cars(63, 83)
# 63
# Stap, totale hoeveelheid subsidie 150, 184264.95039585078
# Total Evs, Total cars(63, 83)
# 52
# Stap, totale hoeveelheid subsidie 150, 59000
# 57
# Stap, totale hoeveelheid subsidie 150, 52755.62882639159
# Total Evs, Total cars(64, 83)
# 64
# Stap, totale hoeveelheid subsidie 151, 185858.44781854414
# Total Evs, Total cars(64, 83)
# 52
# Stap, totale hoeveelheid subsidie 151, 59000
# 57
# Stap, totale hoeveelheid subsidie 151, 52755.62882639159
# Total Evs, Total cars(64, 83)
# 64
# Stap, totale hoeveelheid subsidie 152, 185858.44781854414
# Total Evs, Total cars(64, 83)
# 54
# Stap, totale hoeveelheid subsidie 152, 64200
# 58
# Stap, totale hoeveelheid subsidie 152, 55135.03944896052
# Total Evs, Total cars(64, 83)
# 64
# Stap, totale hoeveelheid subsidie 153, 185858.44781854414
# Total Evs, Total cars(64, 83)
# 57
# Stap, totale hoeveelheid subsidie 153, 72000
# 58
# Stap, totale hoeveelheid subsidie 153, 55135.03944896052
# Total Evs, Total cars(65, 83)
# 65
# Stap, totale hoeveelheid subsidie 154, 187451.9452412375
# Total Evs, Total cars(65, 83)
# 58
# Stap, totale hoeveelheid subsidie 154, 74600
# 58
# Stap, totale hoeveelheid subsidie 154, 55135.03944896052
# Total Evs, Total cars(66, 83)
# 66
# Stap, totale hoeveelheid subsidie 155, 189045.44266393085
# Total Evs, Total cars(66, 83)
# 59
# Stap, totale hoeveelheid subsidie 155, 77200
# 58
# Stap, totale hoeveelheid subsidie 155, 55135.03944896052
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 156, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 59
# Stap, totale hoeveelheid subsidie 156, 77200
# 59
# Stap, totale hoeveelheid subsidie 156, 57844.77980152612
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 157, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 59
# Stap, totale hoeveelheid subsidie 157, 77200
# 59
# Stap, totale hoeveelheid subsidie 157, 57844.77980152612
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 158, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 59
# Stap, totale hoeveelheid subsidie 158, 77200
# 59
# Stap, totale hoeveelheid subsidie 158, 57844.77980152612
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 159, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 59
# Stap, totale hoeveelheid subsidie 159, 77200
# 59
# Stap, totale hoeveelheid subsidie 159, 57844.77980152612
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 160, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 59
# Stap, totale hoeveelheid subsidie 160, 77200
# 59
# Stap, totale hoeveelheid subsidie 160, 57844.77980152612
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 161, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 59
# Stap, totale hoeveelheid subsidie 161, 77200
# 60
# Stap, totale hoeveelheid subsidie 161, 60554.520154091726
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 162, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 60
# Stap, totale hoeveelheid subsidie 162, 80000
# 61
# Stap, totale hoeveelheid subsidie 162, 63264.26050665733
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 163, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 60
# Stap, totale hoeveelheid subsidie 163, 80000
# 61
# Stap, totale hoeveelheid subsidie 163, 63264.26050665733
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 164, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 61
# Stap, totale hoeveelheid subsidie 164, 82800
# 61
# Stap, totale hoeveelheid subsidie 164, 63264.26050665733
# Total Evs, Total cars(67, 83)
# 67
# Stap, totale hoeveelheid subsidie 165, 190522.32190039367
# Total Evs, Total cars(67, 83)
# 61
# Stap, totale hoeveelheid subsidie 165, 82800
# 61
# Stap, totale hoeveelheid subsidie 165, 63264.26050665733
# Total Evs, Total cars(69, 83)
# 69
# Stap, totale hoeveelheid subsidie 166, 193476.0803733193
# Total Evs, Total cars(69, 83)
# 61
# Stap, totale hoeveelheid subsidie 166, 82800
# 61
# Stap, totale hoeveelheid subsidie 166, 63264.26050665733
# Total Evs, Total cars(69, 83)
# 69
# Stap, totale hoeveelheid subsidie 167, 193476.0803733193
# Total Evs, Total cars(69, 83)
# 62
# Stap, totale hoeveelheid subsidie 167, 85600
# 61
# Stap, totale hoeveelheid subsidie 167, 63264.26050665733
# Total Evs, Total cars(69, 83)
# 69
# Stap, totale hoeveelheid subsidie 168, 193476.0803733193
# Total Evs, Total cars(69, 83)
# 62
# Stap, totale hoeveelheid subsidie 168, 85600
# 62
# Stap, totale hoeveelheid subsidie 168, 66350.18973159911
# Total Evs, Total cars(69, 83)
# 69
# Stap, totale hoeveelheid subsidie 169, 193476.0803733193
# Total Evs, Total cars(69, 83)
# 62
# Stap, totale hoeveelheid subsidie 169, 85600
# 62
# Stap, totale hoeveelheid subsidie 169, 66350.18973159911
# Total Evs, Total cars(70, 83)
# 70
# Stap, totale hoeveelheid subsidie 170, 194844.87598480406
# Total Evs, Total cars(70, 83)
# 63
# Stap, totale hoeveelheid subsidie 170, 88600
# 63
# Stap, totale hoeveelheid subsidie 170, 69436.11895654089
# Total Evs, Total cars(70, 83)
# 70
# Stap, totale hoeveelheid subsidie 171, 194844.87598480406
# Total Evs, Total cars(70, 83)
# 65
# Stap, totale hoeveelheid subsidie 171, 94600
# 64
# Stap, totale hoeveelheid subsidie 171, 72522.04818148266
# Total Evs, Total cars(71, 83)
# 71
# Stap, totale hoeveelheid subsidie 172, 196213.67159628883
# Total Evs, Total cars(71, 83)
# 66
# Stap, totale hoeveelheid subsidie 172, 97600
# 64
# Stap, totale hoeveelheid subsidie 172, 72522.04818148266
# Total Evs, Total cars(71, 83)
# 71
# Stap, totale hoeveelheid subsidie 173, 196213.67159628883
# Total Evs, Total cars(71, 83)
# 66
# Stap, totale hoeveelheid subsidie 173, 97600
# 64
# Stap, totale hoeveelheid subsidie 173, 72522.04818148266
# Total Evs, Total cars(71, 83)
# 71
# Stap, totale hoeveelheid subsidie 174, 196213.67159628883
# Total Evs, Total cars(71, 83)
# 66
# Stap, totale hoeveelheid subsidie 174, 97600
# 64
# Stap, totale hoeveelheid subsidie 174, 72522.04818148266
# Total Evs, Total cars(71, 83)
# 71
# Stap, totale hoeveelheid subsidie 175, 196213.67159628883
# Total Evs, Total cars(71, 83)
# 66
# Stap, totale hoeveelheid subsidie 175, 97600
# 64
# Stap, totale hoeveelheid subsidie 175, 72522.04818148266
# Total Evs, Total cars(71, 83)
# 71
# Stap, totale hoeveelheid subsidie 176, 196213.67159628883
# Total Evs, Total cars(71, 83)
# 66
# Stap, totale hoeveelheid subsidie 176, 97600
# 64
# Stap, totale hoeveelheid subsidie 176, 72522.04818148266
# Total Evs, Total cars(71, 83)
# 71
# Stap, totale hoeveelheid subsidie 177, 196213.67159628883
# Total Evs, Total cars(71, 83)
# 67
# Stap, totale hoeveelheid subsidie 177, 100600
# 64
# Stap, totale hoeveelheid subsidie 177, 72522.04818148266
# Total Evs, Total cars(72, 83)
# 72
# Stap, totale hoeveelheid subsidie 178, 197582.4672077736
# Total Evs, Total cars(72, 83)
# 67
# Stap, totale hoeveelheid subsidie 178, 100600
# 64
# Stap, totale hoeveelheid subsidie 178, 72522.04818148266
# Total Evs, Total cars(72, 83)
# 72
# Stap, totale hoeveelheid subsidie 179, 197582.4672077736
# Total Evs, Total cars(72, 83)
# 67
# Stap, totale hoeveelheid subsidie 179, 100600
# 65
# Stap, totale hoeveelheid subsidie 179, 75607.97740642444
# Total Evs, Total cars(72, 83)
# 72
# Stap, totale hoeveelheid subsidie 180, 197582.4672077736
# Total Evs, Total cars(72, 83)
# 67
# Stap, totale hoeveelheid subsidie 180, 100600
# 65
# Stap, totale hoeveelheid subsidie 180, 75607.97740642444
# Total Evs, Total cars(72, 83)
# 72
# Stap, totale hoeveelheid subsidie 181, 197582.4672077736
# Total Evs, Total cars(72, 83)
# 68
# Stap, totale hoeveelheid subsidie 181, 103800
# 65
# Stap, totale hoeveelheid subsidie 181, 75607.97740642444
# Total Evs, Total cars(73, 83)
# 73
# Stap, totale hoeveelheid subsidie 182, 198851.08916396505
# Total Evs, Total cars(73, 83)
# 68
# Stap, totale hoeveelheid subsidie 182, 103800
# 65
# Stap, totale hoeveelheid subsidie 182, 75607.97740642444
# Total Evs, Total cars(73, 83)
# 73
# Stap, totale hoeveelheid subsidie 183, 198851.08916396505
# Total Evs, Total cars(73, 83)
# 68
# Stap, totale hoeveelheid subsidie 183, 103800
# 65
# Stap, totale hoeveelheid subsidie 183, 75607.97740642444
# Total Evs, Total cars(74, 83)
# 74
# Stap, totale hoeveelheid subsidie 184, 200119.7111201565
# Total Evs, Total cars(74, 83)
# 68
# Stap, totale hoeveelheid subsidie 184, 103800
# 66
# Stap, totale hoeveelheid subsidie 184, 79122.32119671909
# Total Evs, Total cars(75, 83)
# 75
# Stap, totale hoeveelheid subsidie 185, 201388.33307634798
# Total Evs, Total cars(75, 83)
# 68
# Stap, totale hoeveelheid subsidie 185, 103800
# 66
# Stap, totale hoeveelheid subsidie 185, 79122.32119671909
# Total Evs, Total cars(75, 83)
# 75
# Stap, totale hoeveelheid subsidie 186, 201388.33307634798
# Total Evs, Total cars(75, 83)
# 68
# Stap, totale hoeveelheid subsidie 186, 103800
# 66
# Stap, totale hoeveelheid subsidie 186, 79122.32119671909
# Total Evs, Total cars(75, 83)
# 75
# Stap, totale hoeveelheid subsidie 187, 201388.33307634798
# Total Evs, Total cars(75, 83)
# 68
# Stap, totale hoeveelheid subsidie 187, 103800
# 66
# Stap, totale hoeveelheid subsidie 187, 79122.32119671909
# Total Evs, Total cars(76, 83)
# 76
# Stap, totale hoeveelheid subsidie 188, 202656.95503253944
# Total Evs, Total cars(76, 83)
# 68
# Stap, totale hoeveelheid subsidie 188, 103800
# 67
# Stap, totale hoeveelheid subsidie 188, 82636.66498701373
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 189, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 189, 103800
# 68
# Stap, totale hoeveelheid subsidie 189, 86151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 190, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 190, 103800
# 68
# Stap, totale hoeveelheid subsidie 190, 86151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 191, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 191, 103800
# 68
# Stap, totale hoeveelheid subsidie 191, 86151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 192, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 192, 103800
# 69
# Stap, totale hoeveelheid subsidie 192, 90151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 193, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 193, 103800
# 69
# Stap, totale hoeveelheid subsidie 193, 90151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 194, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 194, 103800
# 69
# Stap, totale hoeveelheid subsidie 194, 90151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 195, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 195, 103800
# 69
# Stap, totale hoeveelheid subsidie 195, 90151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 196, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 68
# Stap, totale hoeveelheid subsidie 196, 103800
# 69
# Stap, totale hoeveelheid subsidie 196, 90151.00877730838
# Total Evs, Total cars(77, 83)
# 77
# Stap, totale hoeveelheid subsidie 197, 203925.5769887309
# Total Evs, Total cars(77, 83)
# 69
# Stap, totale hoeveelheid subsidie 197, 107200
# 69
# Stap, totale hoeveelheid subsidie 197, 90151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 198, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 198, 107200
# 69
# Stap, totale hoeveelheid subsidie 198, 90151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 199, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 199, 107200
# 70
# Stap, totale hoeveelheid subsidie 199, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 200, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 200, 107200
# 70
# Stap, totale hoeveelheid subsidie 200, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 201, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 201, 107200
# 70
# Stap, totale hoeveelheid subsidie 201, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 202, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 202, 107200
# 70
# Stap, totale hoeveelheid subsidie 202, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 203, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 203, 107200
# 70
# Stap, totale hoeveelheid subsidie 203, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 204, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 204, 107200
# 70
# Stap, totale hoeveelheid subsidie 204, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 205, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 205, 107200
# 70
# Stap, totale hoeveelheid subsidie 205, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 206, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 206, 107200
# 70
# Stap, totale hoeveelheid subsidie 206, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 207, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 207, 107200
# 70
# Stap, totale hoeveelheid subsidie 207, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 208, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 208, 107200
# 70
# Stap, totale hoeveelheid subsidie 208, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 209, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 209, 107200
# 70
# Stap, totale hoeveelheid subsidie 209, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 210, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 210, 107200
# 70
# Stap, totale hoeveelheid subsidie 210, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 211, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 211, 107200
# 70
# Stap, totale hoeveelheid subsidie 211, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 212, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 212, 107200
# 70
# Stap, totale hoeveelheid subsidie 212, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 213, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 213, 107200
# 70
# Stap, totale hoeveelheid subsidie 213, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 214, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 214, 107200
# 70
# Stap, totale hoeveelheid subsidie 214, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 215, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 215, 107200
# 70
# Stap, totale hoeveelheid subsidie 215, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 216, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 216, 107200
# 70
# Stap, totale hoeveelheid subsidie 216, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 217, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 217, 107200
# 70
# Stap, totale hoeveelheid subsidie 217, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 218, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 218, 107200
# 70
# Stap, totale hoeveelheid subsidie 218, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 219, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 219, 107200
# 70
# Stap, totale hoeveelheid subsidie 219, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 220, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 220, 107200
# 70
# Stap, totale hoeveelheid subsidie 220, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 221, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 221, 107200
# 70
# Stap, totale hoeveelheid subsidie 221, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 222, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 222, 107200
# 70
# Stap, totale hoeveelheid subsidie 222, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 223, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 223, 107200
# 70
# Stap, totale hoeveelheid subsidie 223, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 224, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 224, 107200
# 70
# Stap, totale hoeveelheid subsidie 224, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 225, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 225, 107200
# 70
# Stap, totale hoeveelheid subsidie 225, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 226, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 226, 107200
# 70
# Stap, totale hoeveelheid subsidie 226, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 227, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 227, 107200
# 70
# Stap, totale hoeveelheid subsidie 227, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 228, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 228, 107200
# 70
# Stap, totale hoeveelheid subsidie 228, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 229, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 229, 107200
# 70
# Stap, totale hoeveelheid subsidie 229, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 230, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 230, 107200
# 70
# Stap, totale hoeveelheid subsidie 230, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 231, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 231, 107200
# 70
# Stap, totale hoeveelheid subsidie 231, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 232, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 232, 107200
# 70
# Stap, totale hoeveelheid subsidie 232, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 233, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 233, 107200
# 70
# Stap, totale hoeveelheid subsidie 233, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 234, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 234, 107200
# 70
# Stap, totale hoeveelheid subsidie 234, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 235, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 235, 107200
# 70
# Stap, totale hoeveelheid subsidie 235, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 236, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 236, 107200
# 70
# Stap, totale hoeveelheid subsidie 236, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 237, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 237, 107200
# 70
# Stap, totale hoeveelheid subsidie 237, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 238, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 238, 107200
# 70
# Stap, totale hoeveelheid subsidie 238, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 239, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 239, 107200
# 70
# Stap, totale hoeveelheid subsidie 239, 94151.00877730838
# Total Evs, Total cars(78, 83)
# 78
# Stap, totale hoeveelheid subsidie 240, 205101.3563777262
# Total Evs, Total cars(78, 83)
# 69
# Stap, totale hoeveelheid subsidie 240, 107200
# 70
# Stap, totale hoeveelheid subsidie 240, 94151.00877730838

# %%
model_data1 = model1.datacollector.get_model_vars_dataframe()
model_data2 = model2.datacollector.get_model_vars_dataframe()
model_data3 = model3.datacollector.get_model_vars_dataframe()

agent_data1 = model1.datacollector.get_agent_vars_dataframe()
agent_data2 = model2.datacollector.get_agent_vars_dataframe()
agent_data3 = model3.datacollector.get_agent_vars_dataframe()

print(model_data1)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.589155                   2                    3
# 1                     0.589155                   3                    5
# 2                     0.589155                   9                    5
# 3                     0.589155                  11                    5
# 4                     0.589155                  12                    6
# ..                         ...                 ...                  ...
# 235                   0.514056                  78                   53
# 236                   0.514056                  78                   53
# 237                   0.514056                  78                   53
# 238                   0.514056                  78                   53
# 239                   0.512358                  78                   53
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                    0.83                     0.024096
# 1                                    0.83                     0.036145
# 2                                    0.83                     0.108434
# 3                                    0.83                     0.132530
# 4                                    0.83                     0.144578
# ..                                    ...                          ...
# 235                                  0.83                     0.939759
# 236                                  0.83                     0.939759
# 237                                  0.83                     0.939759
# 238                                  0.83                     0.939759
# 239                                  0.83                     0.939759
#
#      Hoeveelheid Subsidie  Percentage late majority met EV  \
# 0             7933.374000                         0.000000
# 1            11900.061000                         0.028571
# 2            35700.183000                         0.085714
# 3            43633.557000                         0.085714
# 4            47600.244000                         0.114286
# ..                    ...                              ...
# 235         205101.356378                         0.828571
# 236         205101.356378                         0.828571
# 237         205101.356378                         0.828571
# 238         205101.356378                         0.828571
# 239         205101.356378                         0.828571
#
#      Percentage laggards met EV
# 0                      0.058824
# 1                      0.058824
# 2                      0.058824
# 3                      0.117647
# 4                      0.117647
# ..                          ...
# 235                    0.764706
# 236                    0.764706
# 237                    0.764706
# 238                    0.764706
# 239                    0.764706
#
# [240 rows x 8 columns]

# %%
print(model_data2)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.497006                   5                    1
# 1                     0.497006                   7                    1
# 2                     0.497006                   8                    1
# 3                     0.497006                   9                    2
# 4                     0.497006                  11                    2
# ..                         ...                 ...                  ...
# 235                   0.591360                  69                   45
# 236                   0.591360                  69                   45
# 237                   0.591360                  69                   45
# 238                   0.591360                  69                   45
# 239                   0.591360                  69                   45
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                    0.77                     0.064935
# 1                                    0.77                     0.090909
# 2                                    0.77                     0.103896
# 3                                    0.77                     0.116883
# 4                                    0.77                     0.142857
# ..                                    ...                          ...
# 235                                  0.77                     0.896104
# 236                                  0.77                     0.896104
# 237                                  0.77                     0.896104
# 238                                  0.77                     0.896104
# 239                                  0.77                     0.896104
#
#      Hoeveelheid Subsidie  Percentage late majority met EV  \
# 0                    1000                         0.058824
# 1                    1400                         0.058824
# 2                    1600                         0.088235
# 3                    1800                         0.088235
# 4                    2200                         0.088235
# ..                    ...                              ...
# 235                107200                         0.705882
# 236                107200                         0.705882
# 237                107200                         0.705882
# 238                107200                         0.705882
# 239                107200                         0.705882
#
#      Percentage laggards met EV
# 0                      0.117647
# 1                      0.176471
# 2                      0.176471
# 3                      0.176471
# 4                      0.235294
# ..                          ...
# 235                    0.764706
# 236                    0.764706
# 237                    0.764706
# 238                    0.764706
# 239                    0.764706
#
# [240 rows x 8 columns]

# %%
print(model_data3)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                      0.50807                   3                    0
# 1                      0.50807                   7                    2
# 2                      0.50807                   7                    4
# 3                      0.50807                   9                    5
# 4                      0.50807                  12                    5
# ..                         ...                 ...                  ...
# 235                    0.59550                  70                   40
# 236                    0.59550                  70                   40
# 237                    0.59550                  70                   40
# 238                    0.59550                  70                   40
# 239                    0.59550                  70                   40
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                    0.78                     0.038462
# 1                                    0.78                     0.089744
# 2                                    0.78                     0.089744
# 3                                    0.78                     0.115385
# 4                                    0.78                     0.153846
# ..                                    ...                          ...
# 235                                  0.78                     0.897436
# 236                                  0.78                     0.897436
# 237                                  0.78                     0.897436
# 238                                  0.78                     0.897436
# 239                                  0.78                     0.897436
#
#      Hoeveelheid Subsidie  Percentage late majority met EV  \
# 0             1500.000000                         0.000000
# 1             3500.000000                         0.000000
# 2             3500.000000                         0.000000
# 3             4500.000000                         0.032258
# 4             6000.000000                         0.064516
# ..                    ...                              ...
# 235          94151.008777                         0.645161
# 236          94151.008777                         0.645161
# 237          94151.008777                         0.645161
# 238          94151.008777                         0.645161
# 239          94151.008777                         0.645161
#
#      Percentage laggards met EV
# 0                      0.058824
# 1                      0.176471
# 2                      0.176471
# 3                      0.176471
# 4                      0.176471
# ..                          ...
# 235                    0.647059
# 236                    0.647059
# 237                    0.647059
# 238                    0.647059
# 239                    0.647059
#
# [240 rows x 8 columns]

# %%
print(vars(model1.schedule.agents[0]))
print(vars(model2.schedule.agents[0]))
print(vars(model3.schedule.agents[0]))
# Out:
# {'unique_id': (6, 7), 'model': <SubsidieModel.SubsidieModel object at 0x7fdec880a9a0>, 'pos': (6, 7), 'agent_type': <TypeAdopter.EARLY_MAJORITY: 2>, 'bezit_auto': True, 'bezit_EV': True, 'vermogen': 82084.66314897436, 'inkomen': 337.5, 'belangstelling': 0.548291724764127, 'leeftijd_auto': 143}
# {'unique_id': (0, 7), 'model': <SubsidieModelLinear.SubsidieModel2 object at 0x7fdec946bcd0>, 'pos': (0, 7), 'agent_type': <TypeAdopter.LAGGARDS: 4>, 'bezit_auto': False, 'bezit_EV': False, 'vermogen': 404812.5, 'inkomen': 1337.5, 'belangstelling': 0.442, 'leeftijd_auto': 240}
# {'unique_id': (2, 1), 'model': <SubsidieModel3.SubsidieModel3 object at 0x7fdec9493520>, 'pos': (2, 1), 'agent_type': <TypeAdopter.EARLY_MAJORITY: 2>, 'bezit_auto': True, 'bezit_EV': True, 'vermogen': 283977.30225817463, 'inkomen': 900.0, 'belangstelling': 0.636, 'leeftijd_auto': 294}

# %%
print(agent_data1)
print(agent_data2)
print(agent_data3)
# Out:
#                   Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (4, 1)    EARLY_ADOPTER        0.835001             58      816.263083
#      (4, 4)    LATE_MAJORITY        0.497234              1      -50.000000
#      (7, 7)   EARLY_MAJORITY        0.635067             71    50281.069154
#      (3, 1)         LAGGARDS        0.441434             21    32068.562005
#      (6, 9)    LATE_MAJORITY        0.497234             37    12079.419023
# ...                      ...             ...            ...             ...
# 240  (2, 6)         LAGGARDS        0.388749            101    57111.971609
#      (1, 8)        INNOVATOR        0.777762            298   290037.501907
#      (8, 8)    LATE_MAJORITY        0.425954            306   449812.500000
#      (9, 2)   EARLY_MAJORITY        0.548292            224   169418.965878
#      (5, 3)         LAGGARDS        0.388749            279   431812.500000
#
#               agent heeft ev
# Step AgentID
# 1    (4, 1)            False
#      (4, 4)            False
#      (7, 7)            False
#      (3, 1)            False
#      (6, 9)            False
# ...                      ...
# 240  (2, 6)             True
#      (1, 8)             True
#      (8, 8)             True
#      (9, 2)             True
#      (5, 3)             True
#
# [24000 rows x 5 columns]
#                   Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (9, 4)   EARLY_MAJORITY          0.5296             41    25783.503239
#      (2, 1)    LATE_MAJORITY          0.4106             47    17734.752770
#      (8, 8)    LATE_MAJORITY          0.4106             55    10853.432515
#      (7, 3)    LATE_MAJORITY          0.4106             51    29865.704347
#      (6, 8)   EARLY_MAJORITY          0.5296             47      253.607354
# ...                      ...             ...            ...             ...
# 240  (7, 2)    LATE_MAJORITY          0.4980            240   155060.632514
#      (9, 6)   EARLY_MAJORITY          0.6360            174   107291.393390
#      (0, 2)         LAGGARDS          0.4420            299   314008.022431
#      (9, 7)   EARLY_MAJORITY          0.6360            175   107586.839302
#      (2, 3)    EARLY_ADOPTER          0.8360            143    81420.826036
#
#               agent heeft ev
# Step AgentID
# 1    (9, 4)            False
#      (2, 1)            False
#      (8, 8)            False
#      (7, 3)            False
#      (6, 8)            False
# ...                      ...
# 240  (7, 2)            False
#      (9, 6)             True
#      (0, 2)             True
#      (9, 7)             True
#      (2, 3)             True
#
# [24000 rows x 5 columns]
#                   Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (9, 1)   EARLY_MAJORITY          0.5380             60    42816.165102
#      (8, 3)    LATE_MAJORITY          0.4175              1    34447.525044
#      (1, 2)   EARLY_MAJORITY          0.5380             66    85412.500000
#      (7, 9)    LATE_MAJORITY          0.4175             44    49514.282349
#      (6, 5)         LAGGARDS          0.3825             66    32500.461265
# ...                      ...             ...            ...             ...
# 240  (9, 9)    LATE_MAJORITY          0.4980            297   353812.500000
#      (7, 5)   EARLY_MAJORITY          0.6360            163   100903.827119
#      (6, 3)         LAGGARDS          0.4420            236   192666.431646
#      (8, 9)   EARLY_MAJORITY          0.6360            187   119610.356199
#      (0, 3)    EARLY_ADOPTER          0.8360            188   127303.899655
#
#               agent heeft ev
# Step AgentID
# 1    (9, 1)            False
#      (8, 3)            False
#      (1, 2)             True
#      (7, 9)            False
#      (6, 5)            False
# ...                      ...
# 240  (9, 9)             True
#      (7, 5)             True
#      (6, 3)             True
#      (8, 9)             True
#      (0, 3)             True
#
# [24000 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Plot instellingen
plt.figure(figsize=(10, 6))

# Lijnen tekenen voor elk model
plt.plot(model_data1['Aantal gekochte EV'], label='Model 1')
plt.plot(model_data2['Aantal gekochte EV'], label='Model 2')
plt.plot(model_data3['Aantal gekochte EV'], label='Model 3')

# Grafiek aankleden
plt.title('Verkoop van EV over tijd')
plt.xlabel('Tijd (stappen)')
plt.ylabel('Aantal gekochte EVs')
plt.legend()  # Voegt de legenda toe
plt.grid(True)

# Toon de grafiek
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2)

x = range(len(model_data1))

# Eerste subplot 
axs[0, 0].plot(x, model_data1["Percerntage EV's van Auto's"], label='Model 1')
axs[0, 0].plot(x, model_data2["Percerntage EV's van Auto's"], label='Model 2')
axs[0, 0].plot(x, model_data3["Percerntage EV's van Auto's"], label='Model 3')

axs[0, 0].set_title("Percentage EV van alle auto's")
axs[0, 0].legend()

# Tweede subplot
axs[0, 1].plot(x, model_data1["Hoeveelheid Subsidie"], label='Model 1')
axs[0, 1].plot(x, model_data2["Hoeveelheid Subsidie"], label='Model 2')
axs[0, 1].plot(x, model_data3["Hoeveelheid Subsidie"], label='Model 3')

axs[0, 1].set_title('Totale hoeveelheid subsidie uitgegeven')
axs[0, 1].legend()


# Derde subplot
axs[1, 0].plot(x, model_data1["Percentage late majority met EV"], label='Model 1')
axs[1, 0].plot(x, model_data2["Percentage late majority met EV"], label='Model 2')
axs[1, 0].plot(x, model_data3["Percentage late majority met EV"], label='Model 3')

axs[1, 0].set_title('Percentage late majority met EV')
axs[1, 0].legend()

# Vierde subplot 
axs[1, 1].plot(x, model_data1['Percentage laggards met EV'], label='Model 1')
axs[1, 1].plot(x, model_data2['Percentage laggards met EV'], label='Model 2')
axs[1, 1].plot(x, model_data3['Percentage laggards met EV'], label='Model 3')

axs[1, 1].set_title("Percentage laggards met EV")
axs[1, 1].legend()

plt.tight_layout()
plt.show()
