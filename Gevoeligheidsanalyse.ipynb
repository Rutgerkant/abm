# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

import random
import numpy as np
import matplotlib.pyplot as plt

initial_waardes_gevoeligheidsanalyse = [0.592, 0.74, 0.888]


avg_percentage_ev = np.zeros((3,20))

for j, i in enumerate(initial_waardes_gevoeligheidsanalyse):
    for iteratie in range(20):
        model1 = SubsidieModel(i)
        for k in range(180):
            model1.step()
        
        data1 = model1.datacollector.get_model_vars_dataframe()
        avg_percentage_ev[j, iteratie]= data1["Percerntage EV's van Auto's"].iloc[-1]
    

x = initial_waardes_gevoeligheidsanalyse

fig, ax = plt.subplots()
for i in range(10):
    ax.scatter(x, avg_percentage_ev[:, i], s=50, label=f'Iteration {i+1}')


ax.set_ylim(0.70, ax.get_ylim()[1])  # Set the lower limit of the y-axis to 2300
ax.legend()
plt.show()


som_neg = 0
som_pos = 0
som_bas = 0
print("Gemiddelde percentage EV's voor elke iteratie:")
for i in range(20):

    for j in range(3):
        if j == 0:
            som_neg += avg_percentage_ev[j][i]

        elif j == 1:
            som_bas += avg_percentage_ev[j][i]
        elif j == 2:
            som_pos += avg_percentage_ev[j][i]
        
        print(f"Iteratie {i+1}: {avg_percentage_ev[:, i]}")

avg_neg = som_neg/20
avg_pos =som_pos/20
avg_bas = som_bas/20
    
    
print(f"-10 {avg_neg}")
print(f"Basis {avg_bas}")
print(f"+10 {avg_pos}")
# Out:
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# STAP1
# Gemiddelde percentage EV's voor elke iteratie:
# Iteratie 1: [0.93760832 0.9100346  0.85278276]
# Iteratie 1: [0.93760832 0.9100346  0.85278276]
# Iteratie 1: [0.93760832 0.9100346  0.85278276]
# Iteratie 2: [0.92123288 0.93368237 0.87625418]
# Iteratie 2: [0.92123288 0.93368237 0.87625418]
# Iteratie 2: [0.92123288 0.93368237 0.87625418]
# Iteratie 3: [0.95570698 0.91666667 0.85982906]
# Iteratie 3: [0.95570698 0.91666667 0.85982906]
# Iteratie 3: [0.95570698 0.91666667 0.85982906]
# Iteratie 4: [0.92560554 0.94086957 0.85667752]
# Iteratie 4: [0.92560554 0.94086957 0.85667752]
# Iteratie 4: [0.92560554 0.94086957 0.85667752]
# Iteratie 5: [0.93434343 0.92140468 0.86597938]
# Iteratie 5: [0.93434343 0.92140468 0.86597938]
# Iteratie 5: [0.93434343 0.92140468 0.86597938]
# Iteratie 6: [0.92943201 0.94700855 0.86225403]
# Iteratie 6: [0.92943201 0.94700855 0.86225403]
# Iteratie 6: [0.92943201 0.94700855 0.86225403]
# Iteratie 7: [0.94482759 0.9318569  0.8573913 ]
# Iteratie 7: [0.94482759 0.9318569  0.8573913 ]
# Iteratie 7: [0.94482759 0.9318569  0.8573913 ]
# Iteratie 8: [0.92320819 0.92227979 0.84562607]
# Iteratie 8: [0.92320819 0.92227979 0.84562607]
# Iteratie 8: [0.92320819 0.92227979 0.84562607]
# Iteratie 9: [0.93379791 0.93513514 0.88020833]
# Iteratie 9: [0.93379791 0.93513514 0.88020833]
# Iteratie 9: [0.93379791 0.93513514 0.88020833]
# Iteratie 10: [0.91958042 0.92442882 0.85395189]
# Iteratie 10: [0.91958042 0.92442882 0.85395189]
# Iteratie 10: [0.91958042 0.92442882 0.85395189]
# Iteratie 11: [0.95081967 0.91433278 0.83676976]
# Iteratie 11: [0.95081967 0.91433278 0.83676976]
# Iteratie 11: [0.95081967 0.91433278 0.83676976]
# Iteratie 12: [0.94513274 0.90569395 0.86115993]
# Iteratie 12: [0.94513274 0.90569395 0.86115993]
# Iteratie 12: [0.94513274 0.90569395 0.86115993]
# Iteratie 13: [0.92830882 0.93378608 0.87565674]
# Iteratie 13: [0.92830882 0.93378608 0.87565674]
# Iteratie 13: [0.92830882 0.93378608 0.87565674]
# Iteratie 14: [0.93975904 0.94158076 0.8650519 ]
# Iteratie 14: [0.93975904 0.94158076 0.8650519 ]
# Iteratie 14: [0.93975904 0.94158076 0.8650519 ]
# Iteratie 15: [0.92832168 0.92730496 0.87328767]
# Iteratie 15: [0.92832168 0.92730496 0.87328767]
# Iteratie 15: [0.92832168 0.92730496 0.87328767]
# Iteratie 16: [0.93027211 0.91408935 0.85714286]
# Iteratie 16: [0.93027211 0.91408935 0.85714286]
# Iteratie 16: [0.93027211 0.91408935 0.85714286]
# Iteratie 17: [0.94014085 0.92       0.88007055]
# Iteratie 17: [0.94014085 0.92       0.88007055]
# Iteratie 17: [0.94014085 0.92       0.88007055]
# Iteratie 18: [0.93086003 0.91370558 0.84954128]
# Iteratie 18: [0.93086003 0.91370558 0.84954128]
# Iteratie 18: [0.93086003 0.91370558 0.84954128]
# Iteratie 19: [0.94207836 0.91652174 0.8537415 ]
# Iteratie 19: [0.94207836 0.91652174 0.8537415 ]
# Iteratie 19: [0.94207836 0.91652174 0.8537415 ]
# Iteratie 20: [0.94250871 0.91260504 0.84983498]
# Iteratie 20: [0.94250871 0.91260504 0.84983498]
# Iteratie 20: [0.94250871 0.91260504 0.84983498]
# -10 0.9351772643767294
# Basis 0.9241493665789005
# +10 0.8606605855176677

# %%
avg_percentage_ev2 = np.zeros((3,10))

for j, i in enumerate(initial_waardes_gevoeligheidsanalyse):
    for iteratie in range(10):
        model2 = SubsidieModel2(i)
        for k in range(240):
            model2.step()
        
        data2 = model2.datacollector.get_model_vars_dataframe()
        avg_percentage_ev2[j, iteratie]= data2["Percerntage EV's van Auto's"].iloc[-1]
    

x = initial_waardes_gevoeligheidsanalyse

fig, ax = plt.subplots()
for i in range(10):
    ax.scatter(x, avg_percentage_ev2[:, i], s=50, label=f'Iteration {i+1}')


ax.set_ylim(0.80, ax.get_ylim()[1])  # Set the lower limit of the y-axis to 2300
ax.legend()
plt.show()

print("Gemiddelde percentage EV's voor elke iteratie:")
for i in range(10):
    print(f"Iteratie {i+1}: {avg_percentage_ev[:, i]}")
# Out:
# Gemiddelde percentage EV's voor elke iteratie:
# Iteratie 1: [0.9295302  0.86896552 0.78846154]
# Iteratie 2: [0.90189329 0.85546218 0.7827529 ]
# Iteratie 3: [0.9100346  0.85268631 0.79270315]
# Iteratie 4: [0.94416244 0.87972509 0.79298246]
# Iteratie 5: [0.89698046 0.89220564 0.76247849]
# Iteratie 6: [0.91385135 0.88927944 0.78175313]
# Iteratie 7: [0.90909091 0.86518771 0.81958763]
# Iteratie 8: [0.90636042 0.86243386 0.81707317]
# Iteratie 9: [0.91370558 0.85714286 0.77834179]
# Iteratie 10: [0.92196007 0.8637138  0.80375427]

# %%
avg_percentage_ev3 = np.zeros((3,10))


for j, i in enumerate(initial_waardes_gevoeligheidsanalyse):
    for iteratie in range(10):
        model3 = SubsidieModel3(i)
        for k in range(240):
            model3.step()
        
        data3 = model3.datacollector.get_model_vars_dataframe()
        avg_percentage_ev3[j, iteratie]= data3["Percerntage EV's van Auto's"].iloc[-1]
    

x = initial_waardes_gevoeligheidsanalyse

fig, ax = plt.subplots()
for i in range(10):
    ax.scatter(x, avg_percentage_ev3[:, i], s=50, label=f'Iteration {i+1}')


ax.set_ylim(0.80, ax.get_ylim()[1])  # Set the lower limit of the y-axis to 2300
ax.legend()
plt.show()

print("Gemiddelde percentage EV's voor elke iteratie:")
for i in range(10):
    print(f"Iteratie {i+1}: {avg_percentage_ev3[:, i]}")
# Out:
# Gemiddelde percentage EV's voor elke iteratie:
# Iteratie 1: [0.93368237 0.91695502 0.88513514]
# Iteratie 2: [0.94661922 0.9357022  0.87889273]
# Iteratie 3: [0.90987868 0.92418773 0.90410959]
# Iteratie 4: [0.93389831 0.91438356 0.91537133]
# Iteratie 5: [0.93877551 0.90689655 0.91245791]
# Iteratie 6: [0.92612613 0.93091537 0.8943662 ]
# Iteratie 7: [0.93356048 0.93311037 0.89597315]
# Iteratie 8: [0.92320819 0.91993186 0.90408526]
# Iteratie 9: [0.94584838 0.92869565 0.90771812]
# Iteratie 10: [0.93783304 0.92487479 0.88107203]
