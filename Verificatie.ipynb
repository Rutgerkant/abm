# %%
from BaseModel import BaseModelSub
from SubsidieModel import SubsidieModel
from SubsidieModelLinear import SubsidieModel2
from SubsidieModel3 import SubsidieModel3

import random
import numpy as np


print("1 stap gelukt")


# Seed doorgeven aan elk model
model1 = SubsidieModel()
model2 = SubsidieModel2()
model3 = SubsidieModel3()


for i in range(192):
    model1.step()
    model2.step()
    model3.step()
# Out:
# 53177.59185842369
# 1 stap gelukt
# /Users/michielvanhouten/Dropbox/Mac/Documents/GitHub/abm/.venv/lib/python3.9/site-packages/mesa/time.py:82: FutureWarning: The AgentSet is experimental. It may be changed or removed in any and all future releases, including patch releases.
# We would love to hear what you think about this new feature. If you have any thoughts, share them with us here: https://github.com/projectmesa/mesa/discussions/1919
#   self._agents: AgentSet = AgentSet(agents, model)
# STAP1

# %%
model_data1 = model1.datacollector.get_model_vars_dataframe()
model_data2 = model2.datacollector.get_model_vars_dataframe()
model_data3 = model3.datacollector.get_model_vars_dataframe()

agent_data1 = model1.datacollector.get_agent_vars_dataframe()
agent_data2 = model2.datacollector.get_agent_vars_dataframe()
agent_data3 = model3.datacollector.get_agent_vars_dataframe()

print(model_data1)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.590560                  28                    9
# 1                     0.590560                  45                   12
# 2                     0.590560                  57                   17
# 3                     0.590560                  73                   22
# 4                     0.590560                  88                   23
# ..                         ...                 ...                  ...
# 187                   0.523339                 610                  385
# 188                   0.523339                 611                  385
# 189                   0.523339                 614                  387
# 190                   0.523339                 616                  387
# 191                   0.521026                 617                  387
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                0.873724                     0.040876
# 1                                0.873724                     0.065693
# 2                                0.873724                     0.083212
# 3                                0.873724                     0.106569
# 4                                0.873724                     0.128467
# ..                                    ...                          ...
# 187                              0.873724                     0.890511
# 188                              0.873724                     0.891971
# 189                              0.873724                     0.896350
# 190                              0.873724                     0.899270
# 191                              0.873724                     0.900730
#
#      Hoeveelheid totale Subsidie  Hoeveelheid Subsidie  \
# 0                   1.110672e+05           3966.687000
# 1                   1.785009e+05           3966.687000
# 2                   2.261012e+05           3966.687000
# 3                   2.895682e+05           3966.687000
# 4                   3.490685e+05           3966.687000
# ..                           ...                   ...
# 187                 1.658440e+06           1268.621956
# 188                 1.659708e+06           1268.621956
# 189                 1.663514e+06           1268.621956
# 190                 1.666051e+06           1268.621956
# 191                 1.667227e+06           1175.779389
#
#      Percentage late majority met EV  Percentage laggards met EV
# 0                           0.030189                    0.023810
# 1                           0.060377                    0.063492
# 2                           0.086792                    0.063492
# 3                           0.105660                    0.079365
# 4                           0.128302                    0.103175
# ..                               ...                         ...
# 187                         0.781132                    0.722222
# 188                         0.781132                    0.722222
# 189                         0.781132                    0.722222
# 190                         0.784906                    0.730159
# 191                         0.788679                    0.730159
#
# [192 rows x 9 columns]

# %%
print(model_data2)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.496411                  19                    7
# 1                     0.496411                  36                   14
# 2                     0.496411                  51                   22
# 3                     0.496411                  68                   30
# 4                     0.496411                  84                   31
# ..                         ...                 ...                  ...
# 187                   0.591038                 610                  395
# 188                   0.591038                 614                  395
# 189                   0.591038                 616                  399
# 190                   0.591038                 617                  399
# 191                   0.591038                 618                  399
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                0.881378                     0.027496
# 1                                0.881378                     0.052098
# 2                                0.881378                     0.073806
# 3                                0.881378                     0.098408
# 4                                0.881378                     0.121563
# ..                                    ...                          ...
# 187                              0.881378                     0.882779
# 188                              0.881378                     0.888567
# 189                              0.881378                     0.891462
# 190                              0.881378                     0.892909
# 191                              0.881378                     0.894356
#
#      Hoeveelheid totale Subsidie  Hoeveelheid Subsidie  \
# 0                           3800                   200
# 1                           7200                   200
# 2                          10200                   200
# 3                          13600                   200
# 4                          16800                   200
# ..                           ...                   ...
# 187                      1189000                  4000
# 188                      1205000                  4000
# 189                      1213000                  4000
# 190                      1217000                  4000
# 191                      1221000                  4000
#
#      Percentage late majority met EV  Percentage laggards met EV
# 0                           0.022472                    0.023810
# 1                           0.044944                    0.047619
# 2                           0.059925                    0.071429
# 3                           0.074906                    0.103175
# 4                           0.089888                    0.111111
# ..                               ...                         ...
# 187                         0.779026                    0.857143
# 188                         0.790262                    0.857143
# 189                         0.794007                    0.857143
# 190                         0.797753                    0.857143
# 191                         0.801498                    0.857143
#
# [192 rows x 9 columns]

# %%
print(model_data3)
# Out:
#      Gemiddelde belangstelling  Aantal gekochte EV  Aantal gekochte FBA  \
# 0                     0.516647                  30                    6
# 1                     0.516647                  57                    6
# 2                     0.516647                  77                    9
# 3                     0.516647                  95                   12
# 4                     0.516647                 109                   14
# ..                         ...                 ...                  ...
# 187                   0.591390                 613                  368
# 188                   0.591390                 618                  368
# 189                   0.591390                 619                  368
# 190                   0.591390                 623                  368
# 191                   0.591390                 623                  368
#
#      Percentage huishoudens in bezit auto  Percerntage EV's van Auto's  \
# 0                                0.890306                     0.042980
# 1                                0.890306                     0.081662
# 2                                0.890306                     0.110315
# 3                                0.890306                     0.136103
# 4                                0.890306                     0.156160
# ..                                    ...                          ...
# 187                              0.890306                     0.878223
# 188                              0.890306                     0.885387
# 189                              0.890306                     0.886819
# 190                              0.890306                     0.892550
# 191                              0.890306                     0.892550
#
#      Hoeveelheid totale Subsidie  Hoeveelheid Subsidie  \
# 0                   3.000000e+04                1000.0
# 1                   5.700000e+04                1000.0
# 2                   7.700000e+04                1000.0
# 3                   9.500000e+04                1000.0
# 4                   1.090000e+05                1000.0
# ..                           ...                   ...
# 187                 1.375350e+06                4000.0
# 188                 1.395350e+06                4000.0
# 189                 1.399350e+06                4000.0
# 190                 1.415350e+06                4000.0
# 191                 1.415350e+06                4000.0
#
#      Percentage late majority met EV  Percentage laggards met EV
# 0                           0.015094                    0.007937
# 1                           0.052830                    0.055556
# 2                           0.083019                    0.079365
# 3                           0.101887                    0.103175
# 4                           0.116981                    0.142857
# ..                               ...                         ...
# 187                         0.788679                    0.793651
# 188                         0.796226                    0.817460
# 189                         0.800000                    0.817460
# 190                         0.803774                    0.817460
# 191                         0.803774                    0.817460
#
# [192 rows x 9 columns]

# %%
print(vars(model1.schedule.agents[0]))
print(vars(model2.schedule.agents[0]))
print(vars(model3.schedule.agents[0]))
# Out:
# {'unique_id': (27, 12), 'model': <SubsidieModel.SubsidieModel object at 0x7f9da8292820>, 'pos': (27, 12), 'agent_type': <TypeAdopter.LATE_MAJORITY: 3>, 'bezit_auto': True, 'bezit_EV': False, 'vermogen': -14587.5, 'inkomen': -75.0, 'belangstelling': 0.433042925946892, 'leeftijd_auto': 224}
# {'unique_id': (24, 13), 'model': <SubsidieModelLinear.SubsidieModel2 object at 0x7f9da82928b0>, 'pos': (24, 13), 'agent_type': <TypeAdopter.EARLY_MAJORITY: 2>, 'bezit_auto': False, 'bezit_EV': False, 'vermogen': 134924.7771330143, 'inkomen': 575.0, 'belangstelling': 0.636, 'leeftijd_auto': 192}
# {'unique_id': (7, 22), 'model': <SubsidieModel3.SubsidieModel3 object at 0x7f9d78841ca0>, 'pos': (7, 22), 'agent_type': <TypeAdopter.EARLY_MAJORITY: 2>, 'bezit_auto': False, 'bezit_EV': False, 'vermogen': 119484.89149431878, 'inkomen': 525.0, 'belangstelling': 0.636, 'leeftijd_auto': 192}

# %%
print(agent_data1)
print(agent_data2)
print(agent_data3)
# Out:
#                    Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (11, 4)         LAGGARDS        0.441434             67     1341.922895
#      (4, 21)         LAGGARDS        0.441434             38    18006.857254
#      (10, 2)    LATE_MAJORITY        0.497234             42     6601.414880
#      (13, 14)   LATE_MAJORITY        0.497234             73    10855.995966
#      (0, 8)         INNOVATOR        0.876934             69     5799.770669
# ...                       ...             ...            ...             ...
# 192  (6, 2)     LATE_MAJORITY        0.433043             95    63947.540030
#      (9, 2)          LAGGARDS        0.393988            255   242636.041662
#      (14, 16)  EARLY_MAJORITY        0.556922            203   172546.572788
#      (20, 25)  EARLY_MAJORITY        0.556922            240   328612.500000
#      (16, 13)   LATE_MAJORITY        0.433043            246   189291.410921
#
#                agent heeft ev
# Step AgentID
# 1    (11, 4)            False
#      (4, 21)            False
#      (10, 2)            False
#      (13, 14)           False
#      (0, 8)             False
# ...                       ...
# 192  (6, 2)              True
#      (9, 2)              True
#      (14, 16)            True
#      (20, 25)            True
#      (16, 13)            True
#
# [150528 rows x 5 columns]
#                    Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (16, 15)   EARLY_ADOPTER          0.7220             55    21747.541922
#      (22, 23)  EARLY_MAJORITY          0.5296             70    85100.000000
#      (16, 1)    EARLY_ADOPTER          0.7220             19    34419.581738
#      (26, 14)   LATE_MAJORITY          0.4106              1     3499.886619
#      (23, 26)  EARLY_MAJORITY          0.5296             41    49360.836351
# ...                       ...             ...            ...             ...
# 192  (26, 21)  EARLY_MAJORITY          0.6360            150    99098.553031
#      (4, 0)          LAGGARDS          0.4420            102    68729.436510
#      (5, 16)    EARLY_ADOPTER          0.8360              2    33412.500000
#      (1, 24)    EARLY_ADOPTER          0.8360            232   188816.262138
#      (2, 5)     EARLY_ADOPTER          0.8360            102    70046.450417
#
#                agent heeft ev
# Step AgentID
# 1    (16, 15)           False
#      (22, 23)           False
#      (16, 1)            False
#      (26, 14)           False
#      (23, 26)           False
# ...                       ...
# 192  (26, 21)            True
#      (4, 0)              True
#      (5, 16)            False
#      (1, 24)             True
#      (2, 5)              True
#
# [150528 rows x 5 columns]
#                    Type Agent  Belangstelling  leeftijd auto  Vermogen Agent  \
# Step AgentID
# 1    (9, 7)          LAGGARDS           0.391             26    48934.973400
#      (24, 5)    LATE_MAJORITY           0.429             23    85262.500000
#      (4, 11)   EARLY_MAJORITY           0.552             57    55173.165003
#      (3, 4)         INNOVATOR           0.782             58      257.618756
#      (18, 18)   LATE_MAJORITY           0.429             41     1470.410564
# ...                       ...             ...            ...             ...
# 192  (23, 2)    LATE_MAJORITY           0.498            188   172188.949475
#      (5, 14)    EARLY_ADOPTER           0.836            117    81427.427566
#      (17, 11)        LAGGARDS           0.442             95    65105.160730
#      (26, 3)   EARLY_MAJORITY           0.636            192   138526.362589
#      (0, 16)    EARLY_ADOPTER           0.836            107    73801.021287
#
#                agent heeft ev
# Step AgentID
# 1    (9, 7)             False
#      (24, 5)            False
#      (4, 11)            False
#      (3, 4)             False
#      (18, 18)           False
# ...                       ...
# 192  (23, 2)             True
#      (5, 14)             True
#      (17, 11)            True
#      (26, 3)            False
#      (0, 16)             True
#
# [150528 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Plot instellingen
plt.figure(figsize=(10, 6))

# Lijnen tekenen voor elk model
plt.plot(model_data1['Aantal gekochte EV'], label='Model 1')
plt.plot(model_data2['Aantal gekochte EV'], label='Model 2')
plt.plot(model_data3['Aantal gekochte EV'], label='Model 3')

# Grafiek aankleden
plt.title('Verkoop van EV over tijd')
plt.xlabel('Tijd (stappen)')
plt.ylabel('Aantal gekochte EVs')
plt.legend()  # Voegt de legenda toe
plt.grid(True)

# Toon de grafiek
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2)

x = range(len(model_data1))

# Eerste subplot 
axs[0, 0].plot(x, model_data1["Percerntage EV's van Auto's"], label='Model 1')
axs[0, 0].plot(x, model_data2["Percerntage EV's van Auto's"], label='Model 2')
axs[0, 0].plot(x, model_data3["Percerntage EV's van Auto's"], label='Model 3')

axs[0, 0].set_title("Percentage EV van alle auto's")
axs[0, 0].legend()

# Tweede subplot
axs[0, 1].plot(x, model_data1["Hoeveelheid Subsidie"], label='Model 1')
axs[0, 1].plot(x, model_data2["Hoeveelheid Subsidie"], label='Model 2')
axs[0, 1].plot(x, model_data3["Hoeveelheid Subsidie"], label='Model 3')

axs[0, 1].set_title('Totale hoeveelheid subsidie uitgegeven')
axs[0, 1].legend()


# Derde subplot
axs[1, 0].plot(x, model_data1["Percentage late majority met EV"], label='Model 1')
axs[1, 0].plot(x, model_data2["Percentage late majority met EV"], label='Model 2')
axs[1, 0].plot(x, model_data3["Percentage late majority met EV"], label='Model 3')

axs[1, 0].set_title('Percentage late majority met EV')
axs[1, 0].legend()

# Vierde subplot 
axs[1, 1].plot(x, model_data1['Percentage laggards met EV'], label='Model 1')
axs[1, 1].plot(x, model_data2['Percentage laggards met EV'], label='Model 2')
axs[1, 1].plot(x, model_data3['Percentage laggards met EV'], label='Model 3')

axs[1, 1].set_title("Percentage laggards met EV")
axs[1, 1].legend()

plt.tight_layout()
plt.show()
